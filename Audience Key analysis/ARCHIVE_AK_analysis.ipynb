# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#load-libraries,-modules" data-toc-modified-id="load-libraries,-modules-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>load libraries, modules</a></span></li><li><span><a href="#Online-audiences-vs.-Offline-audiences" data-toc-modified-id="Online-audiences-vs.-Offline-audiences-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Online audiences vs. Offline audiences</a></span><ul class="toc-item"><li><span><a href="#results" data-toc-modified-id="results-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>results</a></span></li><li><span><a href="#data-wrangling" data-toc-modified-id="data-wrangling-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>data wrangling</a></span></li><li><span><a href="#data-exploration" data-toc-modified-id="data-exploration-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>data exploration</a></span></li></ul></li><li><span><a href="#Data-store-audiences-vs.-non-data-store-audiences" data-toc-modified-id="Data-store-audiences-vs.-non-data-store-audiences-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Data store audiences vs. non-data store audiences</a></span><ul class="toc-item"><li><span><a href="#results" data-toc-modified-id="results-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>results</a></span></li><li><span><a href="#data-wrangling" data-toc-modified-id="data-wrangling-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>data wrangling</a></span></li></ul></li><li><span><a href="#Email-only-audiences" data-toc-modified-id="Email-only-audiences-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Email-only audiences</a></span><ul class="toc-item"><li><span><a href="#Results" data-toc-modified-id="Results-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Results</a></span><ul class="toc-item"><li><span><a href="#all-audiences" data-toc-modified-id="all-audiences-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>all audiences</a></span></li><li><span><a href="#non-DS-audiences" data-toc-modified-id="non-DS-audiences-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>non-DS audiences</a></span></li><li><span><a href="#DS-audiences" data-toc-modified-id="DS-audiences-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>DS audiences</a></span></li></ul></li><li><span><a href="#Data-wrangling" data-toc-modified-id="Data-wrangling-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Data wrangling</a></span></li></ul></li><li><span><a href="#CID-only-audiences" data-toc-modified-id="CID-only-audiences-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>CID-only audiences</a></span><ul class="toc-item"><li><span><a href="#Results" data-toc-modified-id="Results-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Results</a></span><ul class="toc-item"><li><span><a href="#all-audiences" data-toc-modified-id="all-audiences-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>all audiences</a></span></li><li><span><a href="#non-DS-audiences" data-toc-modified-id="non-DS-audiences-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>non-DS audiences</a></span></li><li><span><a href="#DS-audiences" data-toc-modified-id="DS-audiences-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>DS audiences</a></span></li></ul></li></ul></li><li><span><a href="#Address-only-audiences" data-toc-modified-id="Address-only-audiences-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Address-only audiences</a></span><ul class="toc-item"><li><span><a href="#Results" data-toc-modified-id="Results-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Results</a></span><ul class="toc-item"><li><span><a href="#all-audiences" data-toc-modified-id="all-audiences-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>all audiences</a></span></li><li><span><a href="#data-store" data-toc-modified-id="data-store-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>data store</a></span></li></ul></li><li><span><a href="#Data-Wrangling" data-toc-modified-id="Data-Wrangling-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Data Wrangling</a></span></li></ul></li><li><span><a href="#Address-only-audiences-(archive)" data-toc-modified-id="Address-only-audiences-(archive)-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Address-only audiences (archive)</a></span></li><li><span><a href="#PINless-imports-analysis" data-toc-modified-id="PINless-imports-analysis-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>PINless imports analysis</a></span></li><li><span><a href="#PINless-imports-analysis-archive" data-toc-modified-id="PINless-imports-analysis-archive-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>PINless imports analysis archive</a></span></li></ul></div>

# %% [markdown]
# # load libraries, modules

# %%
# import basics
# %load_ext google.cloud.bigquery
from google.cloud import bigquery
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pandas_gbq
pd.set_option('display.max_rows', 500)

# %% [markdown]
# # Online audiences vs. Offline audiences

# %% [markdown]
# ## results
#
# total enabled audiences:
# 21,364
#
# offline audiences: 15,707
#
# online audiences: 5,117

# %% [markdown]
# ## data wrangling

# %% [markdown]
# query all audiences -> enabled, non-FBR

# %%
sql = """
SELECT *
FROM `corp-bi-us-prod.rldb.liveramp_customer_accounts` 
WHERE enabled = true AND customer_link_audience = false;
"""
lcas = pandas_gbq.read_gbq(sql, project_id='liveramp-ts-bigquery')
# Out:
# Downloading: 100%|██████████| 20588/20588 [00:04<00:00, 4590.50rows/s]

# %%
# load table w/all audiences
lcas = pd.read_csv('/Users/aschul/Documents/Documents - aschul1118mac/Code_Base/Investigations/20200417_AK_analysis/all_LCAs.csv')

# %% [markdown]
# query audience type summary -> enabled, non-FBR

# %% [markdown]
# ``` myql
# SELECT type, count(type) AS type_count
# FROM `corp-bi-us-prod.rldb.liveramp_customer_accounts`
# WHERE enabled = true AND customer_link_audience = false
# GROUP BY type
# ORDER BY type_count DESC
# ```

# %%
sql = """
SELECT type, count(type) AS type_count
FROM `corp-bi-us-prod.rldb.liveramp_customer_accounts` 
WHERE enabled = true AND customer_link_audience = false
GROUP BY type
ORDER BY type_count DESC
"""

aud_sum = pandas_gbq.read_gbq(sql, project_id='liveramp-ts-bigquery')
# Out:
# Downloading: 100%|██████████| 9/9 [00:00<00:00, 28.56rows/s]

# %%
# aud_sum = pd.read_csv('/Users/aschul/Documents/Documents - aschul1118mac/Code_Base/Investigations/20200417_AK_analysis/all_LCAs_summary.csv')
aud_sum
# Out:
#                                                type  type_count
# 0                    OfflineLiverampCustomerAccount       15038
# 1                     OnlineLiverampCustomerAccount        4956
# 2              CidPinMappingLiverampCustomerAccount         214
# 3      CidAnonymousIdMappingLiverampCustomerAccount         158
# 4            MuidHeidMappingLiverampCustomerAccount          73
# 5                   MuidOnlyLiverampCustomerAccount          72
# 6                      MatchLiverampCustomerAccount          44
# 7  OfflineFulfillmentMappingLiverampCustomerAccount          17
# 8              IdSyncMappingLiverampCustomerAccount          16

# %% [markdown]
# ## data exploration

# %%
lcas.info()

# %%
lcas.head(2)

# %% [markdown]
# # Data store audiences vs. non-data store audiences

# %% [markdown]
# ## results
# data provider customers - 804 (active customers, defined as having entry in the dms_provider table)
#
# total active audiences - 21,364
# ___________________
#
# offline audiences - 15,707
#
# offline, data store provider audiences - 546
#
# ___________________
#
# online audiences - 5,110
#
# online, data store provider audiences - 1,018
# ___________________
#
# total data store provider audiences - 1,567

# %% [markdown]
# ## data wrangling

# %% [markdown]
# query all data provider customers -> customer status = enabled

# %%
sql = """
SELECT dms_providers.customer_id, customers.id
FROM `corp-bi-us-prod.rldb.dms_providers` AS dms_providers
  INNER JOIN `corp-bi-us-prod.rldb.customers` AS customers
    ON dms_providers.customer_id = customers.id
WHERE customers.status = 1
"""
dms_providers = pandas_gbq.read_gbq(sql, project_id='liveramp-ts-bigquery')
# Out:
# Downloading: 100%|██████████| 824/824 [00:00<00:00, 3307.83rows/s]

# %%
dms_providers.count()
# Out:
# customer_id    824
# id             824
# dtype: int64

# %% [markdown]
# query all data store audiences -> enabled, non-FBR audiences, customer status = enabled

# %%
sql = """
SELECT lr_customer_accounts.id AS audience_id, lr_customer_accounts.display_name AS audience_name, customers.name AS customer_name, customers.id AS customer_id, lr_customer_accounts.type
FROM `corp-bi-us-prod.rldb.dms_segments` AS dms_segments
INNER JOIN `corp-bi-us-prod.rldb.lrc_field_definitions` AS lrc_field_definitions
  ON dms_segments.lrc_field_definition_id = lrc_field_definitions.id
INNER JOIN `corp-bi-us-prod.rldb.liveramp_customer_accounts` AS lr_customer_accounts
  ON lrc_field_definitions.lr_customer_account_id = lr_customer_accounts.id
INNER JOIN `corp-bi-us-prod.rldb.customers` AS customers
  ON lr_customer_accounts.customer_id = customers.id
WHERE lr_customer_accounts.enabled = true AND lr_customer_accounts.customer_link_audience = false AND customers.status = 1
GROUP BY lr_customer_accounts.id, lr_customer_accounts.display_name, customers.name, customers.id, lr_customer_accounts.type
"""
dms_audiences = pandas_gbq.read_gbq(sql, project_id='liveramp-ts-bigquery')
# Out:
# Downloading: 100%|██████████| 1611/1611 [00:00<00:00, 5303.64rows/s]

# %%
dms_audiences
# Out:
#       audience_id                                      audience_name  \
# 0          336529                  Advanced Segments for Parker Fake
# 1          340739         Advanced Segments for Hummingbird Skincare
# 2          336629            Advanced Segments for Naiqu's Car Store
# 3          134979                  Naiqu's Car Store - Car Customers
# 4          482581  Advanced Segments for Customer Profiles: Audie...
# ...           ...                                                ...
# 1606       499151                                    OMG-OMD-Aimmune
# 1607       488091                                   OMG - OMD - Voya
# 1608       465041                   Closerlook - Astrellas - Writers
# 1609       114389                                    GDDS - 23456789
# 1610       200406                                               USET
#
#                                           customer_name  customer_id  \
# 0                                           Parker Fake       531649
# 1                                  Hummingbird Skincare       595289
# 2                                     Naiqu's Car Store       536139
# 3                                     Naiqu's Car Store       536139
# 4     Customer Profiles: Audience Solutions (3p Comb...       626611
# ...                                                 ...          ...
# 1606                                    OMG-OMD-Aimmune       630421
# 1607                                   OMG - OMD - Voya       628111
# 1608                                     Adprime Health       549116
# 1609                                         Ian Meyers       481218
# 1610                                                V12       144191
#
#                                 type
# 0     OfflineLiverampCustomerAccount
# 1     OfflineLiverampCustomerAccount
# 2     OfflineLiverampCustomerAccount
# 3     OfflineLiverampCustomerAccount
# 4     OfflineLiverampCustomerAccount
# ...                              ...
# 1606   OnlineLiverampCustomerAccount
# 1607   OnlineLiverampCustomerAccount
# 1608  OfflineLiverampCustomerAccount
# 1609   OnlineLiverampCustomerAccount
# 1610  OfflineLiverampCustomerAccount
#
# [1611 rows x 5 columns]

# %% [markdown]
# ```mysql
# SELECT lr_customer_accounts.id AS audience_id, lr_customer_accounts.display_name AS audience_name, customers.name AS customer_name, customers.id AS customer_id, lr_customer_accounts.type
# FROM `corp-bi-us-prod.rldb.dms_segments` AS dms_segments
# INNER JOIN `corp-bi-us-prod.rldb.lrc_field_definitions` AS lrc_field_definitions
#   ON dms_segments.lrc_field_definition_id = lrc_field_definitions.id
# INNER JOIN `corp-bi-us-prod.rldb.liveramp_customer_accounts` AS lr_customer_accounts
#   ON lrc_field_definitions.lr_customer_account_id = lr_customer_accounts.id
# INNER JOIN `corp-bi-us-prod.rldb.customers` AS customers
#   ON lr_customer_accounts.customer_id = customers.id
# WHERE lr_customer_accounts.enabled = true AND lr_customer_accounts.customer_link_audience = false AND customers.status = 1
# GROUP BY lr_customer_accounts.id, lr_customer_accounts.display_name, customers.name, customers.id, lr_customer_accounts.type
# ```

# %%
# dms_audiences = pd.read_csv('/Users/aschul/Documents/Documents - aschul1118mac/Code_Base/Investigations/20200417_AK_analysis/all_DS_non_DS_audiences.csv')
dms_audiences
dms_audiences.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1611 entries, 0 to 1610
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   audience_id    1611 non-null   int64
#  1   audience_name  1611 non-null   object
#  2   customer_name  1611 non-null   object
#  3   customer_id    1611 non-null   int64
#  4   type           1611 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 63.1+ KB

# %% [markdown]
# # Email-only audiences

# %% [markdown]
# ## Results
# ### all audiences
# enabled, non-FBR audiences where AK = email and customer = enabled
#
# audiences w/AK as raw email - 5,113
#
# audiences w/AK as hashed email - 253
#
# -------------
# audiences w/AK as MD5 email - 113
#
# audiences w/AK as SHA256 email - 54
#
# audiences w/AK as SHA1 email - 34
#
# audiences w/AK as unknown hash email - 52
#
# ### non-DS audiences
# enabled, non-FBR audiences where AK = email and customer = enabled
#
# non DS audiences w/AK set as raw email - 5,034
#
# non-DS audienecs w/AK set as hashed email - 223
#
# -------------
# audiences w/AK set as MD5 email - 98
#
# audiences w/AK set as SHA256 email - 48
#
# audiences w/AK set as SHA1 email - 26
#
# audiences w/AK set as unknown hash email - 51
#
# ### DS audiences
# enabled, non-FBR audiences where AK = email and customer = enabled
#
# DS audiences w/AK set as raw email - 79
#
# DS audiences w/AK set as hashed email - 30
#
# -------------
# DS audiences w/AK set as MD5 email - 15
#
# DS audiences w/AK set as SHA256 email - 6
#
# DS audiences w/AK set as SHA1 email - 8
#
# DS audiences w/AK set as unknown hash email - 1

# %% [markdown]
# ## Data wrangling

# %% [markdown]
# query all audiences with AK -> enabled, non-FBR audiences, enabled customers

# %%
sql = """
SELECT
  audience_key_labels.id AS ak_id,
  liveramp_customer_accounts.id,
  audience_key_labels.key_index,
  audience_key_labels.label,
  liveramp_customer_accounts.customer_id,
  liveramp_customer_accounts.display_name,
  COUNT(audience_key_labels.id) AS count_AKs
FROM
  `corp-bi-us-prod.rldb.audience_key_labels` AS audience_key_labels
INNER JOIN
  `corp-bi-us-prod.rldb.liveramp_customer_accounts` AS liveramp_customer_accounts
ON
  audience_key_labels.liveramp_customer_account_id = liveramp_customer_accounts.id
INNER JOIN
  `corp-bi-us-prod.rldb.customers` AS customers
ON
  liveramp_customer_accounts.customer_id = customers.id
WHERE
  customers.status = 1
  AND liveramp_customer_accounts.enabled = TRUE
  AND liveramp_customer_accounts.customer_link_audience = FALSE
  AND lower(audience_key_labels.label) LIKE '%email%'
  AND audience_key_labels.key_index = 0
GROUP BY
  liveramp_customer_accounts.id,
  liveramp_customer_accounts.display_name,
  liveramp_customer_accounts.customer_id,
  audience_key_labels.key_index,
  ak_id,
  audience_key_labels.label
HAVING count_AKs = 1
"""
raw_emails_all_audiences = pandas_gbq.read_gbq(sql, project_id='liveramp-ts-bigquery')
# Out:
# Downloading: 100%|██████████| 5444/5444 [00:00<00:00, 7759.47rows/s]

# %%
# raw_emails_all_audiences = pd.read_csv('/Users/aschul/Documents/Documents - aschul1118mac/Code_Base/Investigations/20200417_AK_analysis/email_AKs/query_result.csv')

# %%
raw_emails_all_audiences.head(5)
# Out:
#     ak_id      id  key_index  label  customer_id  \
# 0  181696   79976          0  email       405604
# 1  300046  112509          0  email       532619
# 2  300656  156336          0  Email       532619
# 3  300666  156346          0  Email       532619
# 4  300676  156366          0  Email       532619
#
#                        display_name  count_AKs
# 0                   test mobile pub          1
# 1                     All Shoppers           1
# 2            (FB Aud) $200 LTV List          1
# 3            (FB Aud) $300 LTV List          1
# 4  (FB Aud) 3x Repeat Shoppers List          1

# %%
raw_email_values = pd.DataFrame(raw_emails_all_audiences["label"].value_counts())

# %%
raw_email_values.head()
# Out:
#               label
# email          5113
# MD5             113
# SHA256           54
# hashed_email     52
# SHA1             34

# %%
# filter for key_index = 0

# %%
raw_email_values.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 245 entries, Email to Email/Email
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   245 non-null    int64
# dtypes: int64(1)
# memory usage: 3.8+ KB

# %%
# normalize email columns (raw, MD5, SHA1, SHA256)
raw_emails_all_audiences["label"].replace({"Email":"email", 
                             "Email1":"email",
                             "Email Address":"email",
                             "EmailAddress":"email", 
                             "Emails":"email",
                             "EMAIL":"email",
                             "Email_1":"email",
                             "EmailAddress":"email",
                             "email_address":"email",
                             "EMAIL_ADDRESS":"email",
                             "Email 1":"email",
                             "Email(s)":"email",
                             "email1":"email",
                             "EMAIL_ID":"email",
                             "email1_MD5":"MD5",
                             "emailmd5":"MD5",
                             "profiles.email_address":"email",
                             "EMAIL_ADDR":"email",
                             "SHA256EMAIL1":"email",
                             "email_addr":"email",
                             "MD5EMAIL":"MD5",
                             "EmailAddress":"email",
                             "EMAIL1":"email",
                             "cust_email_addr":"email",
                             "Email_Address":"email",
                             "md5_email":"MD5",
                             "Email_ID":"email",
                             "EMAIL_ADDR_TXT":"email",
                             "emailAddress":"email",
                             "sha1_email":"SHA1",
                             "MD5Email":"MD5",
                             "email_1":"email",
                             "LRI_G_SHA1EMAIL1":"SHA1",
                             "LRI_G_SHA256EMAIL1":"SHA256",
                             "loweremailmd5":"MD5",
                             "email_sha256":"SHA256",
                             "SHA256_EMAIL":"SHA256",
                             "MD5_Email":"MD5",
                             "LRI_DER_SHA256EMAIL1":"SHA256",
                             "email_SHA-1":"SHA1",
                             "sha256email":"SHA256",
                             "email address":"email",
                             "purch_email_addr":"email",
                             "HashedEmail":"hashed_email",
                             "P_EMAIL_ADDRESS":"email",
                             "Member Email Address":"email",
                             "Email Addresses":"email",
                             "email_md5":"MD5",
                             "emails":"email",
                             "Email Hash":"hashed_email",
                             "customer_email":"email",
                             "EMAIL_ADDRESS_":"email",
                             "SHA 256 Email":"SHA256",
                             "EMAILADDRESS":"email",
                             "LRI_DER_SHA1EMAIL1":"SHA1",
                             "email_hash":"hashed_email",
                             "LRI_G_MD5EMAIL1":"MD5",
                             "EMAIL_SHA256":"SHA256",
                             "PII_EMAIL_ADDRESS":"email",
                             "EMail":"email",
                             "Email address":"email",
                             "SHA1_Email":"SHA1",
                             "LRI_DER_MD5EMAIL1":"MD5",
                             "EMAIL_1":"email",
                             "sha256_email":"SHA256",
                             "SHA256EMAIL":"SHA256",
                             "SHA256Email":"email",
                             "emailaddress":"email",
                             "email_id":"email",
                             "SHA1EMAIL":"SHA1",
                             "hashed email":"hashed_email",
                             "SHA256HASHEDEMAIL":"SHA256",
                             "email2":"email",
                             "EMAIL_ADDRESS_1":"email",
                             "md5email":"MD5",
                             "hashedemail":"hashed_email",
                             "EMAIL_HASHED":"hashed_email",
                             "Broker Email":"email",
                             "HASH_MD5_LOWER_EMAIL":"MD5",
                             "profileEmail":"email",
                             "email_Address":"email",
                             "Hashed_Email":"hashed_email",
                             "PER_EMAIL":"email",
                             "Hashed_Email_Address":"email",
                             "Peloton Order Order Email":"email",
                             "EMAIL,FN,LN,,ZIP,CT,PHONE,":"email",
                             "Hashed_Email_ID_Hex":"hashed_email",
                             "#email_lc_md5":"MD5",
                             "MD5_EMAIL":"MD5",
                             "\EMAIL\"":"email",
                             "Customer Email":"email",
                             "CUSTOMERS_SalesOrder_BILLTOLookup::Email":"email",
                             "profile.email":"email",
                             "HASHED_EMAIL":"hashed_email",
                             "sha256email1":"SHA256",
                             "Hashed Email":"hashed_email",
                             "CUST_EMAIL":"email",
                             "SHA256 Email":"SHA256",
                             "email,fn,ln,st,zip,ct,phone,":"email",
                             "best_email":"email",
                             "LRI_G_EMAIL1":"email",
                             "SHA2_EMAIL":"SHA2",
                             "Md5 Email":"MD5",
                             "md5(email1)":"MD5",
                             "master_email":"email",
                             "HASHED_CUST_EMAIL":"hashed_email",
                             "REAL_EMAIL":"email",
                             "email_sha1":"SHA1",
                             "MD5 EMAIL":"MD5",
                             "Email/Email":"email",
                             "hash_email":"hashed_email",
                             "email md5":"MD5",
                             "Email_address":"email",
                             "Email1_SHA-1":"SHA1",
                             "MD5 Hashed Email":"MD5",
                             "EE_EMAIL_ADDRESS":"email",
                             "Email1 Address":"email",
                             "DMD_EMAIL":"email",
                             "QBOVRT_master_email":"email",
                             "lower(b.email_addr_hash_txt)":"hashed_email",
                             "Email1_SHA256":"SHA256",
                             "HashedEmail1":"hashed_email",
                             "CONTACT_EMAIL_ADDR":"email",
                             "Email ":"email",
                             "EmailAddressmd5":"MD5",
                             "CONTACT EMAIL":"email",
                             "MD5EMAIL1":"MD5",
                             "MD5email":"MD5",
                             "sha256email\",470121,624331,470121,UPHE - Onboarding - Salesforce Data\"":"SHA256",
                             "sha256email\",287259,579949,28236,Swirl McGarryBowen - Onboarding\"":"SHA256",
                             "AX_CUREMAIL_10":"email",
                             "Email ":"email",
                             "SHA256_email":"SHA256",
                             "USA_EMAIL":"email",
                             "Right_email":"email",
                             "MDG EMAIL":"MD5",
                             "email3":"email",
                             "sha256email\",287259,579949,28236,Swirl McGarryBowen - Onboarding\"":"SHA256",
                             "sha256email\",470121,624331,470121,UPHE - Onboarding - Salesforce Data\"":"SHA256",
                             "email_SHA_256":"SHA256",
                             "hashed_emailId":"hashed_email",
                             "EMAIL_ADDRESS1":"email",
                             "email_adr1":"email",
                             "EmailAddressHash_MD5":"MD5",
                             "LRI_G_email_address":"email",
                             "DANDRVINSON@EMAIL.COM":"email",
                             "user_email":"email",
                             "Email_hashed":"hashed_email",
                             "P_EMAIL":"email",
                             "Hashed email":"hashed_email",
                             "SHA250Email":"SHA256",
                             "sha256email\",287259,579949,28236,Swirl McGarryBowen - Onboarding\"":"SHA256",
                             "sha256email\",470121,624331,470121,UPHE - Onboarding - Salesforce Data\"":"SHA256",
                             "Email5":"email",
                             "Orders Customer Email":"email",
                             "Encrypted Email address":"hashed_email",
                             "eMail":"email",
                             "patron_email_addr":"email",
                             "Client_Email":"email",
                             "email_01":"email",
                             "emailhash_md5":"MD5",
                             "Person Account: Email":"email",
                             "Email_Appended":"email",
                             "Email_address_hash":"hashed_email",
                             "sha256email\",470121,624331,470121,UPHE - Onboarding - Salesforce Data\"":"SHA256",
                             "EMAIL_HASH":"hashed_email",
                             "Email ID":"email",
                             "email_billing":"email",
                             "PRIMARY_EMAIL_ADDRESS":"email",
                             "Opportunity Email":"email",
                             "CnPh_1_01_Email":"email",
                             "MD5_email":"MD5",
                             "email_address_256hash":"SHA256",
                             "EMAIL ADDR":"email",
                             "sha256email\",154996,542386,15314,StubHub - Salesforce Onboarding\"":"SHA256",
                             "Hash Email":"hashed_email",
                             "prmry_email_addr":"email",
                             "sha256email\",248499,508256,24412,Caesars - Salesforce RFP\"":"SHA256",
                             "MEMBER_EMAIL":"email",
                             "Sha1_Email":"SHA1",
                             "HASH EMAIL ADDR":"hashed_email",
                             "Sha1_Email":"SHA1",
                             "HASH EMAIL ADDR":"hashed_email",
                             "CUS_EMAIL_ADDRESS":"email",
                             "channels.email.address":"email",
                             "\Email1\"\"":"email",
                             "primaryEmail":"email",
                             "sha256email\",313789,533849,313789,Audi - Salesforce Imports\"":"SHA256",
                             "HASEHD_EMAIL":"hashed_email",
                             "\Email1\"\"":"email",
                             "hash email":"hashed_email",
                             "REGI_EMAIL_ADDR":"email",
                             "Customers Email":"email",
                             "email_addres":"email",
                             "sha256email\",116909,533639,11536,Weight Watchers - Onboarding\"":"SHA256",
                             "EMAIL-sha1":"SHA1",
                             "Email Address 1":"email",
                             "Contact Business Email":"email",
                             "\Email1\"\"":"email",
                             "Personal_email":"email",
                             "sha256email\",154996,542386,15314,StubHub - Salesforce Onboarding\"":"SHA256",
                             "EMAIL_MATCH_ID_1":"email",
                             "MD5 Email":"MD5",
                             "associatedemailaddress":"email",
                             "Email_Hash":"hashed_email",
                             "Email_Hash ":"hashed_email",
                             "EMAIL ADDRESS	":"email",
                             "EMAILADDR":"email",
                             "EMAILADDR ":"email",
                             "Contact: Primary Email":"email",
                             "Email Address - Prospects":"email",
                             "sha_email	":"hashed_email",
                             "sha_email":"hashed_email",
                             "primary_contact_primary_email":"email",
                             "EMAIL_ADDR_1":"email",
                             "Primary_Email_Address":"email",
                             "CUST_EMAIL_ADDR":"email",
                             "AlternateEmail":"email"
                            }, inplace = True)

# %%
raw_email_values.head(5)
# Out:
#               label
# email          5113
# MD5             113
# SHA256           54
# hashed_email     52
# SHA1             34

# %%
raw_emails_all_audiences["label"]
# Out:
# 0       email
# 1         MD5
# 2       email
# 3       email
# 4       email
#         ...
# 5961    email
# 5962    email
# 5963    email
# 5964    email
# 5965    email
# Name: label, Length: 5966, dtype: object

# %% [markdown]
# query all audiences with AK like '%email%' -> enabled, non-FBR audiences, enabled customers, data store

# %%
sql = """
SELECT
  audience_key_labels.id AS ak_id,
  liveramp_customer_accounts.id,
  audience_key_labels.key_index,
  audience_key_labels.label,
  liveramp_customer_accounts.customer_id,
  customers.name,
  liveramp_customer_accounts.display_name,
  COUNT(audience_key_labels.id) AS count_AKs
FROM
  `corp-bi-us-prod.rldb.audience_key_labels` AS audience_key_labels
INNER JOIN
  `corp-bi-us-prod.rldb.liveramp_customer_accounts` AS liveramp_customer_accounts
ON
  audience_key_labels.liveramp_customer_account_id = liveramp_customer_accounts.id
INNER JOIN
  `corp-bi-us-prod.rldb.customers` AS customers
ON
  liveramp_customer_accounts.customer_id = customers.id
WHERE
  liveramp_customer_accounts.id IN (
              SELECT
                lr_customer_accounts.id
              FROM
                `corp-bi-us-prod.rldb.dms_segments` AS dms_segments
              INNER JOIN
                `corp-bi-us-prod.rldb.lrc_field_definitions` AS lrc_field_definitions
              ON
                dms_segments.lrc_field_definition_id = lrc_field_definitions.id
              INNER JOIN
                `corp-bi-us-prod.rldb.liveramp_customer_accounts` AS lr_customer_accounts
              ON
                lrc_field_definitions.lr_customer_account_id = lr_customer_accounts.id
              INNER JOIN
                `corp-bi-us-prod.rldb.customers` AS customers
              ON
                lr_customer_accounts.customer_id = customers.id
              WHERE
                lr_customer_accounts.enabled = TRUE
                AND lr_customer_accounts.customer_link_audience = FALSE
                AND customers.status = 1
              GROUP BY
                lr_customer_accounts.id)
  AND customers.status = 1
  AND liveramp_customer_accounts.enabled = TRUE
  AND liveramp_customer_accounts.customer_link_audience = FALSE
  AND LOWER(audience_key_labels.label) LIKE '%email%'
  AND audience_key_labels.key_index = 0
GROUP BY
  liveramp_customer_accounts.id,
  liveramp_customer_accounts.display_name,
  liveramp_customer_accounts.customer_id,
  customers.name,
  audience_key_labels.key_index,
  ak_id,
  audience_key_labels.label
HAVING
  count_AKs = 1
"""
raw_emails_DS = pandas_gbq.read_gbq(sql, project_id='liveramp-ts-bigquery')
# Out:
# Downloading: 100%|██████████| 109/109 [00:00<00:00, 248.94rows/s]

# %%
# raw_emails_DS = pd.read_csv('/Users/aschul/Documents/Documents - aschul1118mac/Code_Base/Investigations/20200417_AK_analysis/email_AKs/query_result_DS.csv')

# %%
raw_emails_DS.head(5)
# Out:
#     ak_id      id  key_index        label  customer_id  \
# 0  599836  392676          0        Email       607196
# 1  511479  325469          0  PERSONEMAIL       516396
# 2  305996  160426          0        Email       543596
# 3  730091  320109          0       EMAIL1       531379
# 4  504669  318709          0       EMAIL1       531379
#
#                       name                            display_name  count_AKs
# 0    TRAINING Joseph Dolan      TRAINING Joseph Dolan - Onboarding          1
# 1           Leadspace, Inc                          Leadspace Test          1
# 2  [training] *Karen Situ*      [training] Karen Situ - Onboarding          1
# 3                 180byTWO               180byTWO - Simple Onboard          1
# 4                 180byTWO  180byTwo - PII Onboarding (Individual)          1

# %%
raw_emails_DS.count()
# Out:
# ak_id           109
# id              109
# key_index       109
# label           109
# customer_id     109
# name            109
# display_name    109
# count_AKs       109
# dtype: int64

# %%
raw_emails_DS_values = pd.DataFrame(raw_emails_DS["label"].value_counts())
raw_emails_DS_values
# Out:
#               label
# email            79
# MD5              15
# SHA1              8
# SHA256            6
# hashed_email      1

# %%
# normalize email columns (raw, MD5, SHA1, SHA256)
raw_emails_DS["label"].replace({"Email":"email", 
                             "Email1":"email",
                             "Email Address":"email",
                             "EmailAddress":"email", 
                             "Emails":"email",
                             "EMAIL":"email",
                             "Email_1":"email",
                             "EmailAddress":"email",
                             "email_address":"email",
                             "EMAIL_ADDRESS":"email",
                             "Email 1":"email",
                             "Email(s)":"email",
                             "email1":"email",
                             "EMAIL_ID":"email",
                             "email1_MD5":"MD5",
                             "emailmd5":"MD5",
                             "profiles.email_address":"email",
                             "EMAIL_ADDR":"email",
                             "SHA256EMAIL1":"email",
                             "email_addr":"email",
                             "MD5EMAIL":"MD5",
                             "EmailAddress":"email",
                             "EMAIL1":"email",
                             "cust_email_addr":"email",
                             "Email_Address":"email",
                             "md5_email":"MD5",
                             "Email_ID":"email",
                             "EMAIL_ADDR_TXT":"email",
                             "emailAddress":"email",
                             "sha1_email":"SHA1",
                             "MD5Email":"MD5",
                             "email_1":"email",
                             "LRI_G_SHA1EMAIL1":"SHA1",
                             "LRI_G_SHA256EMAIL1":"SHA256",
                             "loweremailmd5":"MD5",
                             "email_sha256":"SHA256",
                             "SHA256_EMAIL":"SHA256",
                             "MD5_Email":"MD5",
                             "LRI_DER_SHA256EMAIL1":"SHA256",
                             "email_SHA-1":"SHA1",
                             "sha256email":"SHA256",
                             "email address":"email",
                             "purch_email_addr":"email",
                             "HashedEmail":"hashed_email",
                             "P_EMAIL_ADDRESS":"email",
                             "Member Email Address":"email",
                             "Email Addresses":"email",
                             "email_md5":"MD5",
                             "emails":"email",
                             "Email Hash":"hashed_email",
                             "customer_email":"email",
                             "EMAIL_ADDRESS_":"email",
                             "SHA 256 Email":"SHA256",
                             "EMAILADDRESS":"email",
                             "LRI_DER_SHA1EMAIL1":"SHA1",
                             "email_hash":"hashed_email",
                             "LRI_G_MD5EMAIL1":"MD5",
                             "EMAIL_SHA256":"SHA256",
                             "PII_EMAIL_ADDRESS":"email",
                             "EMail":"email",
                             "Email address":"email",
                             "SHA1_Email":"SHA1",
                             "LRI_DER_MD5EMAIL1":"MD5",
                             "EMAIL_1":"email",
                             "sha256_email":"SHA256",
                             "SHA256EMAIL":"SHA256",
                             "SHA256Email":"email",
                             "emailaddress":"email",
                             "email_id":"email",
                             "SHA1EMAIL":"SHA1",
                             "hashed email":"hashed_email",
                             "SHA256HASHEDEMAIL":"SHA256",
                             "email2":"email",
                             "EMAIL_ADDRESS_1":"email",
                             "md5email":"MD5",
                             "hashedemail":"hashed_email",
                             "EMAIL_HASHED":"hashed_email",
                             "Broker Email":"email",
                             "HASH_MD5_LOWER_EMAIL":"MD5",
                             "profileEmail":"email",
                             "email_Address":"email",
                             "Hashed_Email":"hashed_email",
                             "PER_EMAIL":"email",
                             "Hashed_Email_Address":"email",
                             "Peloton Order Order Email":"email",
                             "EMAIL,FN,LN,,ZIP,CT,PHONE,":"email",
                             "Hashed_Email_ID_Hex":"hashed_email",
                             "#email_lc_md5":"MD5",
                             "MD5_EMAIL":"MD5",
                             "\EMAIL\"":"email",
                             "Customer Email":"email",
                             "CUSTOMERS_SalesOrder_BILLTOLookup::Email":"email",
                             "profile.email":"email",
                             "HASHED_EMAIL":"hashed_email",
                             "sha256email1":"SHA256",
                             "Hashed Email":"hashed_email",
                             "CUST_EMAIL":"email",
                             "SHA256 Email":"SHA256",
                             "email,fn,ln,st,zip,ct,phone,":"email",
                             "best_email":"email",
                             "LRI_G_EMAIL1":"email",
                             "SHA2_EMAIL":"SHA2",
                             "Md5 Email":"MD5",
                             "md5(email1)":"MD5",
                             "master_email":"email",
                             "HASHED_CUST_EMAIL":"hashed_email",
                             "REAL_EMAIL":"email",
                             "email_sha1":"SHA1",
                             "MD5 EMAIL":"MD5",
                             "Email/Email":"email",
                             "hash_email":"hashed_email",
                             "email md5":"MD5",
                             "Email_address":"email",
                             "Email1_SHA-1":"SHA1",
                             "MD5 Hashed Email":"MD5",
                             "EE_EMAIL_ADDRESS":"email",
                             "Email1 Address":"email",
                             "DMD_EMAIL":"email",
                             "QBOVRT_master_email":"email",
                             "lower(b.email_addr_hash_txt)":"hashed_email",
                             "Email1_SHA256":"SHA256",
                             "HashedEmail1":"hashed_email",
                             "CONTACT_EMAIL_ADDR":"email",
                             "Email ":"email",
                             "EmailAddressmd5":"MD5",
                             "CONTACT EMAIL":"email",
                             "MD5EMAIL1":"MD5",
                             "MD5email":"MD5",
                             "sha256email\",470121,624331,470121,UPHE - Onboarding - Salesforce Data\"":"SHA256",
                             "sha256email\",287259,579949,28236,Swirl McGarryBowen - Onboarding\"":"SHA256",
                             "AX_CUREMAIL_10":"email",
                             "Email ":"email",
                             "SHA256_email":"SHA256",
                             "USA_EMAIL":"email",
                             "Right_email":"email",
                             "MDG EMAIL":"MD5",
                             "email3":"email",
                             "sha256email\",287259,579949,28236,Swirl McGarryBowen - Onboarding\"":"SHA256",
                             "sha256email\",470121,624331,470121,UPHE - Onboarding - Salesforce Data\"":"SHA256",
                             "email_SHA_256":"SHA256",
                             "hashed_emailId":"hashed_email",
                             "EMAIL_ADDRESS1":"email",
                             "email_adr1":"email",
                             "EmailAddressHash_MD5":"MD5",
                             "LRI_G_email_address":"email",
                             "DANDRVINSON@EMAIL.COM":"email",
                             "user_email":"email",
                             "Email_hashed":"hashed_email",
                             "P_EMAIL":"email",
                             "Hashed email":"hashed_email",
                             "SHA250Email":"SHA256",
                             "sha256email\",287259,579949,28236,Swirl McGarryBowen - Onboarding\"":"SHA256",
                             "sha256email\",470121,624331,470121,UPHE - Onboarding - Salesforce Data\"":"SHA256",
                             "Email5":"email",
                             "Orders Customer Email":"email",
                             "Encrypted Email address":"hashed_email",
                             "eMail":"email",
                             "patron_email_addr":"email",
                             "Client_Email":"email",
                             "email_01":"email",
                             "emailhash_md5":"MD5",
                             "Person Account: Email":"email",
                             "Email_Appended":"email",
                             "Email_address_hash":"hashed_email",
                             "sha256email\",470121,624331,470121,UPHE - Onboarding - Salesforce Data\"":"SHA256",
                             "EMAIL_HASH":"hashed_email",
                             "Email ID":"email",
                             "email_billing":"email",
                             "PRIMARY_EMAIL_ADDRESS":"email",
                             "Opportunity Email":"email",
                             "CnPh_1_01_Email":"email",
                             "MD5_email":"MD5",
                             "email_address_256hash":"SHA256",
                             "EMAIL ADDR":"email",
                             "sha256email\",154996,542386,15314,StubHub - Salesforce Onboarding\"":"SHA256",
                             "Hash Email":"hashed_email",
                             "prmry_email_addr":"email",
                             "sha256email\",248499,508256,24412,Caesars - Salesforce RFP\"":"SHA256",
                             "MEMBER_EMAIL":"email",
                             "Sha1_Email":"SHA1",
                             "HASH EMAIL ADDR":"hashed_email",
                             "Sha1_Email":"SHA1",
                             "HASH EMAIL ADDR":"hashed_email",
                             "CUS_EMAIL_ADDRESS":"email",
                             "channels.email.address":"email",
                             "\Email1\"\"":"email",
                             "primaryEmail":"email",
                             "sha256email\",313789,533849,313789,Audi - Salesforce Imports\"":"SHA256",
                             "HASEHD_EMAIL":"hashed_email",
                             "\Email1\"\"":"email",
                             "hash email":"hashed_email",
                             "REGI_EMAIL_ADDR":"email",
                             "Customers Email":"email",
                             "email_addres":"email",
                             "sha256email\",116909,533639,11536,Weight Watchers - Onboarding\"":"SHA256",
                             "EMAIL-sha1":"SHA1",
                             "Email Address 1":"email",
                             "Contact Business Email":"email",
                             "\Email1\"\"":"email",
                             "Personal_email":"email",
                             "sha256email\",154996,542386,15314,StubHub - Salesforce Onboarding\"":"SHA256",
                             "EMAIL_MATCH_ID_1":"email",
                             "MD5 Email":"MD5",
                             "associatedemailaddress":"email",
                             "Email_Hash":"hashed_email",
                             "Email_Hash ":"hashed_email",
                             "EMAIL ADDRESS	":"email",
                             "EMAILADDR":"email",
                             "EMAILADDR ":"email",
                             "Contact: Primary Email":"email",
                             "Email Address - Prospects":"email",
                             "sha_email	":"hashed_email",
                             "sha_email":"hashed_email",
                             "primary_contact_primary_email":"email",
                             "EMAIL_ADDR_1":"email",
                             "Primary_Email_Address":"email",
                             "CUST_EMAIL_ADDR":"email",
                             "AlternateEmail":"email",
                             "PERSONEMAIL":"email",
                             "email_address_01":"email"
                            }, inplace = True)

# %% [markdown]
# Follow up question: check cases where online audiences have email audience key label

# %% [markdown]
# # CID-only audiences

# %% [markdown]
# ## Results
# ### all audiences
# enabled, non-FBR audiences where AK = CID and customer = enabled
#
# audiences w/AK as CID - 5,703
#
# offline audiences w/AK as CID - 4,292
#
# online audiences w/AK as CID - 1,162
#
# other audiences w/AK as CID - 249
#
# -------------
#
#
# ### non-DS audiences
# enabled, non-FBR audiences where AK = CID and customer = enabled
#
# non DS audiences w/AK set as CID - 5,285
#
# non DS offline audiences w/AK as CID - 4050
#
# non DS online audiences w/AK as CID - 986
#
# -------------
#
#
# ### DS audiences
# enabled, non-FBR audiences where AK = CID and customer = enabled
#
# DS audiences w/AK set as CID - 418
#
# DS offline audiences w/AK as CID - 242
#
# DS online audiences w/AK as CID - 176
#
# -------------

# %% [markdown]
# query all audiences with AK like '%id%' -> enabled, non-FBR audiences, enabled customers, not like: aaid, IDFA, cookie, device id, email, pel, identity_link, idl, liveramp, LR ID 1, LRID, MAID, mobile, order_id, PELID
#
# CID definition methodology: after combing through AK labels strings that match AK like '%id%', IDs that do not resemble CIDs were removed. This analysis thus treats a CID as a synthetic identifier distinguished from IDLs/PELs, cookies, and device IDs.

# %%
sql = """
SELECT
  liveramp_customer_accounts.id AS audience_id,
  customers.id AS cust_id, 
  audience_key_labels.key_index,
  lower(audience_key_labels.label) AS aks,
  COUNT(audience_key_labels.id) AS count_aks
FROM
  `corp-bi-us-prod.rldb.audience_key_labels` AS audience_key_labels
INNER JOIN
  `corp-bi-us-prod.rldb.liveramp_customer_accounts` AS liveramp_customer_accounts
ON
  audience_key_labels.liveramp_customer_account_id = liveramp_customer_accounts.id
INNER JOIN
  `corp-bi-us-prod.rldb.customers` AS customers
ON
  liveramp_customer_accounts.customer_id = customers.id
WHERE
  audience_key_labels.key_index = 0
  AND lower(audience_key_labels.label) LIKE '%id%'
  AND lower(audience_key_labels.label) NOT LIKE '%aaid%'
  AND lower(audience_key_labels.label) NOT LIKE '%idfa%'
  AND lower(audience_key_labels.label) NOT LIKE '%cookie%'
  AND lower(audience_key_labels.label) NOT LIKE '%device id%'
  AND lower(audience_key_labels.label) NOT LIKE '%device_id%'
  AND lower(audience_key_labels.label) NOT LIKE '%device%'
  AND lower(audience_key_labels.label) NOT LIKE '%email%'
  AND lower(audience_key_labels.label) NOT LIKE '%pel%'
  AND lower(audience_key_labels.label) NOT LIKE '%identity_link%'
  AND lower(audience_key_labels.label) NOT LIKE '%idl%'
  AND lower(audience_key_labels.label) NOT LIKE '%liveramp%'
  AND lower(audience_key_labels.label) NOT LIKE '%lr id 1%'
  AND lower(audience_key_labels.label) NOT LIKE '%lrid%'
  AND lower(audience_key_labels.label) NOT LIKE '%maid%'
  AND lower(audience_key_labels.label) NOT LIKE '%mobile%'
  AND lower(audience_key_labels.label) NOT LIKE '%order_id%'
  AND lower(audience_key_labels.label) NOT LIKE '%pelid%'
  AND lower(audience_key_labels.label) NOT LIKE '%fb_ext_id%'
  AND lower(audience_key_labels.label) NOT LIKE '%identitylink%'
  AND lower(audience_key_labels.label) NOT LIKE '%muid%'
  AND lower(audience_key_labels.label) NOT LIKE '%abilitec%'
  AND lower(audience_key_labels.label) NOT LIKE '%acxiom_id%'
  AND lower(audience_key_labels.label) NOT LIKE '%extern_id%'
  AND lower(audience_key_labels.label) NOT LIKE '%cnsmr_link_id%'
  AND lower(audience_key_labels.label) NOT LIKE '%ttd_android%'
  AND customers.status = 1
  AND liveramp_customer_accounts.enabled = TRUE
  AND liveramp_customer_accounts.customer_link_audience = FALSE
  AND audience_key_labels.key_index = 0
GROUP BY
  1, 2, 3, 4
HAVING
  COUNT(audience_key_labels.id) = 1
"""

CIDs_all_audiences = pandas_gbq.read_gbq(sql, project_id='liveramp-ts-bigquery')
# Out:
# Downloading: 100%|██████████| 5703/5703 [00:00<00:00, 8995.10rows/s]

# %%
# CIDs_all_audiences = pd.read_csv('/Users/aschul/Documents/Documents - aschul1118mac/Code_Base/Investigations/20200417_AK_analysis/CID_AKs/query_result.csv')

# %%
CIDs_all_audiences.head()
# Out:
#    audience_id  cust_id  key_index         aks  count_aks
# 0       501221   550486          0  customerid          1
# 1       502581   586779          0         sid          1
# 2       247989   554196          0          id          1
# 3       246779   540626          0          id          1
# 4       246629   506766          0         cid          1

# %%
CID_values = pd.DataFrame(CIDs_all_audiences["aks"].value_counts())

# %%
CID_values.head(10)
# Out:
#                     aks
# customer id         596
# client customer id  553
# customerid          388
# id                  338
# customer_id         307
# ccid                251
# record_id           132
# mbid                123
# cid                 104
# client_customer_id   92

# %%
CID_values.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 814 entries, Customer ID to mb_id
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   814 non-null    int64
# dtypes: int64(1)
# memory usage: 12.7+ KB

# %%
CID_values["aks"]
# Out:
# customer id           596
# client customer id    553
# customerid            388
# id                    338
# customer_id           307
#                      ...
# aiq_bizid               1
# buyid                   1
# amperity_id             1
# cac_id                  1
# neo player id c         1
# Name: aks, Length: 672, dtype: int64

# %% [markdown]
# query all audiences with AK like '%ID%' -> enabled, non-FBR audiences, enabled customers, data store

# %%
sql = """
SELECT
  liveramp_customer_accounts.id AS audience_id,
  customers.id AS cust_id, 
  audience_key_labels.key_index AS key_index,
  lower(audience_key_labels.label) AS label,
  COUNT(audience_key_labels.id) AS count_AK
FROM
  `corp-bi-us-prod.rldb.audience_key_labels` AS audience_key_labels
INNER JOIN
  `corp-bi-us-prod.rldb.liveramp_customer_accounts` AS liveramp_customer_accounts
ON
  audience_key_labels.liveramp_customer_account_id = liveramp_customer_accounts.id
INNER JOIN
  `corp-bi-us-prod.rldb.customers` AS customers
ON
  liveramp_customer_accounts.customer_id = customers.id
WHERE
liveramp_customer_accounts.id IN (
              SELECT
                lr_customer_accounts.id
              FROM
                `corp-bi-us-prod.rldb.dms_segments` AS dms_segments
              INNER JOIN
                `corp-bi-us-prod.rldb.lrc_field_definitions` AS lrc_field_definitions
              ON
                dms_segments.lrc_field_definition_id = lrc_field_definitions.id
              INNER JOIN
                `corp-bi-us-prod.rldb.liveramp_customer_accounts` AS lr_customer_accounts
              ON
                lrc_field_definitions.lr_customer_account_id = lr_customer_accounts.id
              INNER JOIN
                `corp-bi-us-prod.rldb.customers` AS customers
              ON
                lr_customer_accounts.customer_id = customers.id
              WHERE
                lr_customer_accounts.enabled = TRUE
                AND lr_customer_accounts.customer_link_audience = FALSE
                AND customers.status = 1
              GROUP BY
                lr_customer_accounts.id) 
  AND 
  audience_key_labels.key_index = 0
  AND lower(audience_key_labels.label) LIKE '%id%'
  AND lower(audience_key_labels.label) NOT LIKE '%aaid%'
  AND lower(audience_key_labels.label) NOT LIKE '%idfa%'
  AND lower(audience_key_labels.label) NOT LIKE '%cookie%'
  AND lower(audience_key_labels.label) NOT LIKE '%device id%'
  AND lower(audience_key_labels.label) NOT LIKE '%device_id%'
  AND lower(audience_key_labels.label) NOT LIKE '%device%'
  AND lower(audience_key_labels.label) NOT LIKE '%email%'
  AND lower(audience_key_labels.label) NOT LIKE '%pel%'
  AND lower(audience_key_labels.label) NOT LIKE '%identity_link%'
  AND lower(audience_key_labels.label) NOT LIKE '%idl%'
  AND lower(audience_key_labels.label) NOT LIKE '%liveramp%'
  AND lower(audience_key_labels.label) NOT LIKE '%lr id 1%'
  AND lower(audience_key_labels.label) NOT LIKE '%lrid%'
  AND lower(audience_key_labels.label) NOT LIKE '%maid%'
  AND lower(audience_key_labels.label) NOT LIKE '%mobile%'
  AND lower(audience_key_labels.label) NOT LIKE '%order_id%'
  AND lower(audience_key_labels.label) NOT LIKE '%pelid%'
  AND lower(audience_key_labels.label) NOT LIKE '%fb_ext_id%'
  AND lower(audience_key_labels.label) NOT LIKE '%identitylink%'
  AND lower(audience_key_labels.label) NOT LIKE '%muid%'
  AND lower(audience_key_labels.label) NOT LIKE '%abilitec%'
  AND lower(audience_key_labels.label) NOT LIKE '%acxiom_id%'
  AND lower(audience_key_labels.label) NOT LIKE '%extern_id%'
  AND lower(audience_key_labels.label) NOT LIKE '%cnsmr_link_id%'
  AND lower(audience_key_labels.label) NOT LIKE '%ttd_android%'
  AND customers.status = 1
  AND liveramp_customer_accounts.enabled = TRUE
  AND liveramp_customer_accounts.customer_link_audience = FALSE
  AND audience_key_labels.key_index = 0
  AND liveramp_customer_accounts.type = "OfflineLiverampCustomerAccount"
GROUP BY
  1, 2, 3, 4
HAVING
  COUNT(audience_key_labels.id) = 1
"""
CIDs_DS_audiences = pandas_gbq.read_gbq(sql, project_id='liveramp-ts-bigquery')
# Out:
# Downloading: 100%|██████████| 242/242 [00:00<00:00, 1119.98rows/s]

# %%
# CIDs_DS_audiences = pd.read_csv('/Users/aschul/Documents/Documents - aschul1118mac/Code_Base/Investigations/20200417_AK_analysis/CID_AKs/query_result_DS.csv')

# %%
CIDs_DS_audiences.head(5)
# Out:
#    audience_id  cust_id  key_index       label  count_AK
# 0       247989   554196          0          id         1
# 1       213686   567909          0          id         1
# 2       216216   535709          0      snapid         1
# 3       217376   500619          0    aiq_hhid         1
# 4       215906   510756          0  stiristaid         1

# %%
CID_values_DS_audiences = pd.DataFrame(CIDs_DS_audiences["label"].value_counts())

# %%
CID_values_DS_audiences.head(10)
# Out:
#                     label
# id                     72
# agile_id               27
# rnc_reg_id             24
# customerid             22
# aiq_hhid               16
# client customer id     11
# stiristaid             11
# customer id            10
# lalvoterid              9
# dedupe_id               9

# %% [markdown]
# # Address-only audiences

# %% [markdown]
# ## Results
#
# ### all audiences
# enabled, non-FBR audiences where customer = enabled and AK = address
#
# all audiences w/ak = address -> 1,145
#
# offline audiences w/ak = address -> 1,133
#
# online audiences w/ak = address -> 12
#
# ### data store
#
# all audiences w/ak = address -> 90
#
# offline audiences w/ak = address -> 90
#
# online audiences w/ak = address -> 0

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# query all audiences for # of aks between 4 and 7 inclusive, enabled customers, enabled audiences, non-FBR

# %%
sql = """
SELECT
  audience_key_labels.liveramp_customer_account_id,
  customers.id AS customer_id,
  customers.name AS customer_name,
  COUNT(audience_key_labels.id) AS ak_count,
  STRING_AGG(LOWER(audience_key_labels.label)) AS aks,
  liveramp_customer_accounts.type
FROM
  `corp-bi-us-prod.rldb.audience_key_labels` AS audience_key_labels
INNER JOIN
  `corp-bi-us-prod.rldb.liveramp_customer_accounts` AS liveramp_customer_accounts
ON
  audience_key_labels.liveramp_customer_account_id = liveramp_customer_accounts.id
INNER JOIN
  `corp-bi-us-prod.rldb.customers` AS customers
ON
  liveramp_customer_accounts.customer_id = customers.id
WHERE
  customers.status = 1
  AND liveramp_customer_accounts.enabled = TRUE
  AND liveramp_customer_accounts.customer_link_audience = FALSE

GROUP BY
  1,
  2,
  3,
  6
HAVING
  ak_count > 3
  AND ak_count < 8
  AND aks NOT LIKE "%transaction%"
  AND aks NOT LIKE "%amount%"
  AND aks NOT LIKE "%aaid%"
  AND aks NOT LIKE "%email%"
  AND aks NOT LIKE "%ordinal%"
ORDER BY
  ak_count DESC
"""
address_aks = pandas_gbq.read_gbq(sql, project_id='liveramp-ts-bigquery')
# Out:
# Downloading: 100%|██████████| 1145/1145 [00:00<00:00, 2371.36rows/s]

# %%
address_aks.head(5)
# Out:
#    liveramp_customer_account_id  customer_id                customer_name  \
# 0                        187916       539129  [training] Karmelia Elliott
# 1                        187966       539129  [training] Karmelia Elliott
# 2                        187906       539129  [training] Karmelia Elliott
# 3                        354429       576169                      Epsilon
# 4                        460371       576169                      Epsilon
#
#    ak_count                                                aks  \
# 0         7  fst_name_1,lst_name_1,city_town_1,postal_cd_1,...
# 1         7  fst_name_1,lst_name_1,city_town_1,postal_cd_1,...
# 2         7  fst_name_1,lst_name_1,city_town_1,postal_cd_1,...
# 3         7  zip,city,state,last_name,first_name,address_li...
# 4         7  zip,city,state,last_name,first_name,address_li...
#
#                              type
# 0  OfflineLiverampCustomerAccount
# 1  OfflineLiverampCustomerAccount
# 2  OfflineLiverampCustomerAccount
# 3  OfflineLiverampCustomerAccount
# 4  OfflineLiverampCustomerAccount

# %%
# count types

# %% [markdown]
# query all audiences for # of aks between 4 and 7 inclusive, enabled customers, enabled audiences, non-FBR, DS

# %%
sql = """
SELECT
  audience_key_labels.liveramp_customer_account_id,
  customers.id AS customer_id,
  customers.name AS customer_name,
  COUNT(audience_key_labels.id) AS ak_count,
  STRING_AGG(LOWER(audience_key_labels.label)) AS aks,
  liveramp_customer_accounts.type
FROM
  `corp-bi-us-prod.rldb.audience_key_labels` AS audience_key_labels
INNER JOIN
  `corp-bi-us-prod.rldb.liveramp_customer_accounts` AS liveramp_customer_accounts
ON
  audience_key_labels.liveramp_customer_account_id = liveramp_customer_accounts.id
INNER JOIN
  `corp-bi-us-prod.rldb.customers` AS customers
ON
  liveramp_customer_accounts.customer_id = customers.id
WHERE
liveramp_customer_accounts.id IN (
              SELECT
                lr_customer_accounts.id
              FROM
                `corp-bi-us-prod.rldb.dms_segments` AS dms_segments
              INNER JOIN
                `corp-bi-us-prod.rldb.lrc_field_definitions` AS lrc_field_definitions
              ON
                dms_segments.lrc_field_definition_id = lrc_field_definitions.id
              INNER JOIN
                `corp-bi-us-prod.rldb.liveramp_customer_accounts` AS lr_customer_accounts
              ON
                lrc_field_definitions.lr_customer_account_id = lr_customer_accounts.id
              INNER JOIN
                `corp-bi-us-prod.rldb.customers` AS customers
              ON
                lr_customer_accounts.customer_id = customers.id
              WHERE
                lr_customer_accounts.enabled = TRUE
                AND lr_customer_accounts.customer_link_audience = FALSE
                AND customers.status = 1
              GROUP BY
                lr_customer_accounts.id) AND
  customers.status = 1
  AND liveramp_customer_accounts.enabled = TRUE
  AND liveramp_customer_accounts.customer_link_audience = FALSE
  AND liveramp_customer_accounts.type = "OfflineLiverampCustomerAccount"
GROUP BY
  1,
  2,
  3,
  6
HAVING
  ak_count > 3
  AND ak_count < 8
  AND aks NOT LIKE "%transaction%"
  AND aks NOT LIKE "%amount%"
  AND aks NOT LIKE "%aaid%"
  AND aks NOT LIKE "%email%"
  AND aks NOT LIKE "%ordinal%"
ORDER BY
  ak_count DESC
"""
address_aks_DS = pandas_gbq.read_gbq(sql, project_id='liveramp-ts-bigquery')
# Out:
# Downloading: 100%|██████████| 90/90 [00:00<00:00, 456.17rows/s]

# %%
address_aks_DS
# Out:
#     liveramp_customer_account_id  customer_id  \
# 0                         113519       576169
# 1                         177096       437078
# 2                          97599       576169
# 3                          98699       576169
# 4                         341589       576169
# 5                         408301       538859
# 6                         356929       437078
# 7                         134309       144191
# 8                         133059       520876
# 9                         105779       144191
# 10                        483981       437078
# 11                        484431       437078
# 12                        164496       437078
# 13                        164476       437078
# 14                        164506       437078
# 15                        164516       437078
# 16                        164466       437078
# 17                        164486       437078
# 18                        159466       576169
# 19                           617       576169
# 20                        206896       521086
# 21                        297579       437078
# 22                        163946       437078
# 23                        382189       576169
# 24                        354429       576169
# 25                        352589       437078
# 26                        352599       437078
# 27                        438361       531379
# 28                        438351       531379
# 29                        400001       437078
# 30                         43346       144191
# 31                        246559       144191
# 32                         98099       576169
# 33                         71756       517946
# 34                         47836       436078
# 35                        436001       538859
# 36                        378609       517946
# 37                        377749       517946
# 38                        378899        57384
# 39                        310859       517946
# 40                         88826       521086
# 41                         55256       144191
# 42                        179186        57384
# 43                        149996       144191
# 44                         70326       517946
# 45                        453021       517946
# 46                        360969       517946
# 47                        360659       517946
# 48                        335419       592649
# 49                        276419       517946
# 50                        210446       521086
# 51                        212576       517946
# 52                        177856       517946
# 53                        408321       538859
# 54                        408311       538859
# 55                        408341       538859
# 56                        408331       538859
# 57                        408271       538859
# 58                        408291       538859
# 59                        408281       538859
# 60                        110309       520876
# 61                         69846       517946
# 62                        388459       517946
# 63                        326349       517946
# 64                        167686       544656
# 65                         80516        57384
# 66                         22356       400648
# 67                         22876       437078
# 68                         13669       213651
# 69                        257969       144191
# 70                        130109       144191
# 71                        129689       509776
# 72                         32246       511386
# 73                        201756       507516
# 74                        405041       517946
# 75                        354059       517946
# 76                        127729       144191
# 77                        352289       560826
# 78                        250369       144191
# 79                         29536       437078
# 80                         17056       144191
# 81                        499111       437078
# 82                        365899       517946
# 83                         93976       434788
# 84                          9658       400648
# 85                          6928       576169
# 86                        362739       538859
# 87                        471521       190211
# 88                        386619       538859
# 89                        262299       511386
#
#                           customer_name  ak_count  \
# 0                               Epsilon         7
# 1                                   ALC         7
# 2                               Epsilon         7
# 3                               Epsilon         7
# 4                               Epsilon         7
# 5                              Claritas         7
# 6                                   ALC         7
# 7                                   V12         7
# 8                              Windfall         7
# 9                                   V12         7
# 10                                  ALC         7
# 11                                  ALC         7
# 12                                  ALC         7
# 13                                  ALC         7
# 14                                  ALC         7
# 15                                  ALC         7
# 16                                  ALC         7
# 17                                  ALC         7
# 18                              Epsilon         7
# 19                              Epsilon         7
# 20  Lighthouse List - Ameribase Digital         7
# 21                                  ALC         7
# 22                                  ALC         7
# 23                              Epsilon         7
# 24                              Epsilon         7
# 25                                  ALC         7
# 26                                  ALC         7
# 27                             180byTWO         7
# 28                             180byTWO         7
# 29                                  ALC         7
# 30                                  V12         7
# 31                                  V12         6
# 32                              Epsilon         6
# 33                        ASL Marketing         6
# 34                              Alliant         6
# 35                             Claritas         6
# 36                        ASL Marketing         6
# 37                        ASL Marketing         6
# 38                                  SMS         6
# 39                        ASL Marketing         6
# 40  Lighthouse List - Ameribase Digital         6
# 41                                  V12         6
# 42                                  SMS         6
# 43                                  V12         6
# 44                        ASL Marketing         6
# 45                        ASL Marketing         6
# 46                        ASL Marketing         6
# 47                        ASL Marketing         6
# 48                    TRAINING - Shauna         6
# 49                        ASL Marketing         6
# 50  Lighthouse List - Ameribase Digital         6
# 51                        ASL Marketing         6
# 52                        ASL Marketing         6
# 53                             Claritas         6
# 54                             Claritas         6
# 55                             Claritas         6
# 56                             Claritas         6
# 57                             Claritas         6
# 58                             Claritas         6
# 59                             Claritas         6
# 60                             Windfall         6
# 61                        ASL Marketing         6
# 62                        ASL Marketing         6
# 63                        ASL Marketing         6
# 64                             Zipscene         6
# 65                                  SMS         6
# 66                              Webbula         6
# 67                                  ALC         6
# 68                             Relevate         6
# 69                                  V12         6
# 70                                  V12         6
# 71               Audience Elements APAC         6
# 72                     #Home by Vendigi         6
# 73                         T Rowe Price         6
# 74                        ASL Marketing         6
# 75                        ASL Marketing         6
# 76                                  V12         6
# 77                  Delphine Radet Test         6
# 78                                  V12         6
# 79                                  ALC         6
# 80                                  V12         6
# 81                                  ALC         6
# 82                        ASL Marketing         6
# 83                          MeritDirect         6
# 84                              Webbula         6
# 85                              Epsilon         5
# 86                             Claritas         4
# 87                             Geoscape         4
# 88                             Claritas         4
# 89                     #Home by Vendigi         4
#
#                                                   aks  \
# 0   zip,city,state,lastname,address_line_1,address...
# 1   zip,city,state,lastname,zipplus4,firstname,add...
# 2   city,state,last name,first name,postal code,ad...
# 3   city,state,last name,first name,postal code,ad...
# 4   zip,city,state,last_name,first_name,address_li...
# 5     zip,city,zip4,state,address1,lastname,firstname
# 6   zip,city,state,lastname,zipplus4,firstname,add...
# 7   city,state,zip_code,address_1,address_2,last_n...
# 8         city,zip4,fname,lname,state,address,zipcode
# 9   zip,city,state,last name,first name,address li...
# 10  zip,city,state,lastname,zipplus4,firstname,add...
# 11  zip,city,state,lastname,zipplus4,firstname,add...
# 12  zip,city,state,lastname,zipplus4,firstname,add...
# 13  zip,city,state,lastname,zipplus4,firstname,add...
# 14  zip,city,state,lastname,zipplus4,firstname,add...
# 15  zip,city,state,lastname,zipplus4,firstname,add...
# 16  zip,city,state,lastname,zipplus4,firstname,add...
# 17  zip,city,state,lastname,zipplus4,firstname,add...
# 18  city,state,postal_cd,last_name_raw,address_lin...
# 19          zip,city,last,first,state,street1,street2
# 20     zip,city,zip4,state,address,lastname,firstname
# 21  zip,city,state,lastname,zipplus4,firstname,add...
# 22  zip,city,state,lastname,zipplus4,firstname,add...
# 23  zip,city,state,last_name,first_name,address_li...
# 24  zip,city,state,last_name,first_name,address_li...
# 25  zip,city,state,lastname,zipplus4,firstname,add...
# 26  zip,city,state,lastname,zipplus4,firstname,add...
# 27  zip,city,state,last_name,first_name,primary_ad...
# 28  zip,city,state,last_name,first_name,primary_ad...
# 29  zip,city,state,lastname,zipplus4,firstname,add...
# 30  zip,city,state,address1,address2,lastname,firs...
# 31  zip,city,state,last name,first name,street add...
# 32  city,state,last name,first name,postal code,ad...
# 33  st,zip,city,address,studentlastname,studentfir...
# 34  last_name,first_name,full_address,primary_city...
# 35  city,state,zip code,last name,first name,stree...
# 36         zip,city,state,address1,lastname,firstname
# 37         zip,city,state,address1,lastname,firstname
# 38         zip,city,state,address1,lastname,firstname
# 39         zip,city,state,address1,lastname,firstname
# 40          zip,city,state,address,lastname,firstname
# 41                zip,city,last,first,state,address_1
# 42         zip,city,state,address1,lastname,firstname
# 43         zip,city,state,address1,lastname,firstname
# 44         zip,city,state,address1,lastname,firstname
# 45         zip,city,state,address1,lastname,firstname
# 46         zip,city,state,address1,lastname,firstname
# 47         zip,city,state,address1,lastname,firstname
# 48       zip,city,state,address1,last_name,first_name
# 49         zip,city,state,address1,lastname,firstname
# 50          zip,city,state,address,lastname,firstname
# 51         zip,city,state,address1,lastname,firstname
# 52             st,zip,city,address,lastname,firstname
# 53         zip,city,state,address1,lastname,firstname
# 54         zip,city,state,address1,lastname,firstname
# 55         zip,city,state,address1,lastname,firstname
# 56         zip,city,state,address1,lastname,firstname
# 57         zip,city,state,address1,lastname,firstname
# 58         zip,city,state,address1,lastname,firstname
# 59         zip,city,state,address1,lastname,firstname
# 60       city,zip9,state,address,last_name,first_name
# 61  st,zip,city,address,studentlastname,studentfir...
# 62         zip,city,state,address1,lastname,firstname
# 63         zip,city,state,address1,lastname,firstname
# 64  city,state,zip code,last name,first name,stree...
# 65         zip,city,state,address1,lastname,firstname
# 66       city,zip5,state,address,last_name,first_name
# 67  last name,first name,company zip,company city,...
# 68      city,st_cd,addr_1,zip_cd,last_name,first_name
# 69                 city,last,zip5,first,state,address
# 70                  zip,city,last,first,state,address
# 71    city,state,address1,lastname,postcode,firstname
# 72  city,state,street,zipcode,lastname,firstandmid...
# 73       zip,city,state,address1,last_name,first_name
# 74         zip,city,state,address1,lastname,firstname
# 75         zip,city,state,address1,lastname,firstname
# 76        zip,city,state,address,last_name,first_name
# 77  zip,city,state,last_name,first_name,address_li...
# 78                 city,last,zip5,first,state,address
# 79      zip,city,state,address_1,last_name,first_name
# 80      city,st_cd,addr_1,zip_cd,last_name,first_name
# 81      zip,city,state,lastname,firstname,addressline
# 82         zip,city,state,address1,lastname,firstname
# 83  last_name,first_name,business_zip,business_cit...
# 84   city,state,address,address2,last_name,first_name
# 85                        city,last,addr1,first,state
# 86                    zip,address1,lastname,firstname
# 87            zip,last_name,first_name,address_line_1
# 88                    zip,address1,lastname,firstname
# 89                             zip,city,state,address
#
#                               type
# 0   OfflineLiverampCustomerAccount
# 1   OfflineLiverampCustomerAccount
# 2   OfflineLiverampCustomerAccount
# 3   OfflineLiverampCustomerAccount
# 4   OfflineLiverampCustomerAccount
# 5   OfflineLiverampCustomerAccount
# 6   OfflineLiverampCustomerAccount
# 7   OfflineLiverampCustomerAccount
# 8   OfflineLiverampCustomerAccount
# 9   OfflineLiverampCustomerAccount
# 10  OfflineLiverampCustomerAccount
# 11  OfflineLiverampCustomerAccount
# 12  OfflineLiverampCustomerAccount
# 13  OfflineLiverampCustomerAccount
# 14  OfflineLiverampCustomerAccount
# 15  OfflineLiverampCustomerAccount
# 16  OfflineLiverampCustomerAccount
# 17  OfflineLiverampCustomerAccount
# 18  OfflineLiverampCustomerAccount
# 19  OfflineLiverampCustomerAccount
# 20  OfflineLiverampCustomerAccount
# 21  OfflineLiverampCustomerAccount
# 22  OfflineLiverampCustomerAccount
# 23  OfflineLiverampCustomerAccount
# 24  OfflineLiverampCustomerAccount
# 25  OfflineLiverampCustomerAccount
# 26  OfflineLiverampCustomerAccount
# 27  OfflineLiverampCustomerAccount
# 28  OfflineLiverampCustomerAccount
# 29  OfflineLiverampCustomerAccount
# 30  OfflineLiverampCustomerAccount
# 31  OfflineLiverampCustomerAccount
# 32  OfflineLiverampCustomerAccount
# 33  OfflineLiverampCustomerAccount
# 34  OfflineLiverampCustomerAccount
# 35  OfflineLiverampCustomerAccount
# 36  OfflineLiverampCustomerAccount
# 37  OfflineLiverampCustomerAccount
# 38  OfflineLiverampCustomerAccount
# 39  OfflineLiverampCustomerAccount
# 40  OfflineLiverampCustomerAccount
# 41  OfflineLiverampCustomerAccount
# 42  OfflineLiverampCustomerAccount
# 43  OfflineLiverampCustomerAccount
# 44  OfflineLiverampCustomerAccount
# 45  OfflineLiverampCustomerAccount
# 46  OfflineLiverampCustomerAccount
# 47  OfflineLiverampCustomerAccount
# 48  OfflineLiverampCustomerAccount
# 49  OfflineLiverampCustomerAccount
# 50  OfflineLiverampCustomerAccount
# 51  OfflineLiverampCustomerAccount
# 52  OfflineLiverampCustomerAccount
# 53  OfflineLiverampCustomerAccount
# 54  OfflineLiverampCustomerAccount
# 55  OfflineLiverampCustomerAccount
# 56  OfflineLiverampCustomerAccount
# 57  OfflineLiverampCustomerAccount
# 58  OfflineLiverampCustomerAccount
# 59  OfflineLiverampCustomerAccount
# 60  OfflineLiverampCustomerAccount
# 61  OfflineLiverampCustomerAccount
# 62  OfflineLiverampCustomerAccount
# 63  OfflineLiverampCustomerAccount
# 64  OfflineLiverampCustomerAccount
# 65  OfflineLiverampCustomerAccount
# 66  OfflineLiverampCustomerAccount
# 67  OfflineLiverampCustomerAccount
# 68  OfflineLiverampCustomerAccount
# 69  OfflineLiverampCustomerAccount
# 70  OfflineLiverampCustomerAccount
# 71  OfflineLiverampCustomerAccount
# 72  OfflineLiverampCustomerAccount
# 73  OfflineLiverampCustomerAccount
# 74  OfflineLiverampCustomerAccount
# 75  OfflineLiverampCustomerAccount
# 76  OfflineLiverampCustomerAccount
# 77  OfflineLiverampCustomerAccount
# 78  OfflineLiverampCustomerAccount
# 79  OfflineLiverampCustomerAccount
# 80  OfflineLiverampCustomerAccount
# 81  OfflineLiverampCustomerAccount
# 82  OfflineLiverampCustomerAccount
# 83  OfflineLiverampCustomerAccount
# 84  OfflineLiverampCustomerAccount
# 85  OfflineLiverampCustomerAccount
# 86  OfflineLiverampCustomerAccount
# 87  OfflineLiverampCustomerAccount
# 88  OfflineLiverampCustomerAccount
# 89  OfflineLiverampCustomerAccount

# %%
2) PINless AKs
3) reformat results

# %% [markdown]
# # Address-only audiences (archive)

# %% [markdown]
# Query all audiences and audience keys

# %% [markdown]
# ```mysql
# SELECT
#   audience_key_labels.liveramp_customer_account_id,
#   audience_key_labels.key_index,
#   audience_key_labels.label,
#   liveramp_customer_accounts.customer_id,
#   liveramp_customer_accounts.display_name,
#   liveramp_customer_accounts.type,
#   COUNT(audience_key_labels.id)
# FROM
#   audience_key_labels
# INNER JOIN
#   liveramp_customer_accounts
# ON
#   audience_key_labels.liveramp_customer_account_id = liveramp_customer_accounts.id
# INNER JOIN
#   customers
# ON
#   liveramp_customer_accounts.customer_id = customers.id
# WHERE
#   customers.status = 1
#   AND liveramp_customer_accounts.enabled = TRUE
#   AND liveramp_customer_accounts.customer_link_audience = FALSE
# GROUP BY liveramp_customer_accounts.id
# ```

# %%
sql = """


"""

# %%
all_AKs = pd.read_csv('/Users/aschul/Documents/Documents - aschul1118mac/Code_Base/Investigations/20200417_AK_analysis/address_AKs/all_AKs_raw.csv')

# %%
all_AKs.head(5)
# Out:
#       id  liveramp_customer_account_id  key_index     label   id.1  \
# 0    918                           121          0      zip4  121.0
# 1    348                           251          0  DL Acct#  251.0
# 2  11378                           591          0       uid  591.0
# 3    928                           607          0     email  607.0
# 4  12248                           617          0     first  617.0
#
#   customer_id  data_partner_thrift_identifier           display_name  \
# 0       47644                              21            IXI Digital
# 1      111451                              44               Dataline
# 2      199441                              84                   i360
# 3      337461                              64  Madison Logic - Email
# 4      576169                              54    Epsilon - Evergreen
#
#    volume_limit           updated_at  ...  evaluation_tos_accepted_by  merged  \
# 0           NaN  2020-05-12 05:20:26  ...                         NaN       0
# 1           NaN  2020-04-07 10:22:17  ...                         NaN       0
# 2           NaN  2020-05-11 16:42:25  ...                         NaN       0
# 3           NaN  2018-10-18 18:30:49  ...                         NaN       0
# 4           NaN  2020-05-11 21:12:14  ...                         NaN       0
#
#    query_rate_estimate esp_key reference_liveramp_customer_account_id  \
# 0                  NaN     NaN                                    NaN
# 1                  NaN     NaN                                    NaN
# 2                  NaN     NaN                                    NaN
# 3                  NaN     NaN                                 101819
# 4                  NaN     NaN                                    NaN
#
#              email_alias  custom_billing_rule_id  custom_billing_rule_type  \
# 0       ixi@liveramp.com                     NaN                       NaN
# 1  dataline@liveramp.com                     NaN                       NaN
# 2      i360@liveramp.com                     NaN                       NaN
# 3   bombora@liveramp.com                     NaN                       NaN
# 4   epsilon@liveramp.com                     NaN                       NaN
#
#                      encryption_key  enable_match_reports
# 0  19b9bd190c8cd3af70a640d29781fefd                   0.0
# 1  e729dc08e327f2eaef7fb62ca5fe7f0a                   1.0
# 2  81aa0c2b5dd6c9563eb617d317df3378                   0.0
# 3  e5782f17c88e4f9cc9a6b1b7623d1a0d                   1.0
# 4  c6b2264c008c35b82afa33e69dbe8043                   0.0
#
# [5 rows x 70 columns]

# %%
all_AKs["label"] = all_AKs["label"].str.lower()
all_AKs["label"] = all_AKs["label"].str.strip()

# %%
all_AKs["label"].replace(['name','fnln','fn ln','fn_ln','lnfn','ln fn','ln_fn','full_name','envname','envelopename','hname1',
             'full name','fullname',
            ], 'Fn & Ln', inplace = True)

all_AKs["label"].replace(['lname','last_name','last','last name','lastname','cust_last_name','customer_last_name',
             'nea_last_nm','last_nme','lst_name','last','name last','contactlastname','rpm_last_name',
             'recipient_last_name','cust_last_nm','last_nm','tsmart_last_name','last name (parsed)',
             'voters_lastname','consumerlastname','primary_last','name_last','contact last name',
             'new_lastname','namelast','ln'
            ], 'Last Name', inplace = True)

all_AKs["label"].replace(['fname','first_name','first','first name','firstname','cust_first_name','customer_first_name',
             'nea_first_nm','frst_nme','fst_name','first','fist_name','name first','contactfirstname',
             'rpm_first_name','recipient_first_name','cust_first_nm','first_nm','tsmart_first_name',
             'first name (parsed)','voters_firstname','consumerfirstname','primary_first','name_first',
             'frist name','contact first name','new_firstname','firs','namefirst','fn'
            ], 'First Name', inplace = True)

all_AKs["label"].replace(['street','address','address ','baseaddr','street address','maddress','residential_address',
             'streetaddress','applicant street','abt_trillium_street_addr','address ','guest_address',
             'mailingstreet','block name','full_address','tsmart_full_address','svc_address','addressline'
             'mailing_addresses_addressline','primary address line','block_name','home street address','extraaddress',
             'prior address','primary_address','addressline','vaddress','street_address',
             'mailing_addresses_addressline','registrationaddr1 registrationaddr2','xaddress',
             'residence_addresses_addressline','mailing address'
            ], 'Street', inplace = True)

all_AKs["label"].replace(['street1','street 1','address1','address 1','address_1','street address 1','address_line_1','raddr1',
             'street_address_1','address line 1','addr_line1','addr1','mailaddr1','primaryaddress','addr_line_1',
             'addrline1','maddress','maddr1','maddress1','primary_address_line','nea_hm_st','rpm_address_line1',
             'address line1','regaddrline1','address1_str','cust_addr_line_1','registrationaddr1',
             'address 1 (us/canada)','emp addr1','radr1','consumeraddress1','primaryaddress1','mailaddrline1',
             'address_line1','new_street1','addr_1','new_street1','primary_address1','addr 1','primary address',
             'line1','registrationaddr1','homeaddress1','prim_address_line1','registrationaddr1','addressline1',
             'street address1','reg_addr1','street address_1','deliveryline1'
            ], 'Street1', inplace = True)

all_AKs["label"].replace(['street2','street 2','address2','address 2','address_2','address_line_2','streetaddress2',
             'nea_hm_addr_2','secondaryaddress','address line2','address3','address_line2','street address 2',
             'registrationaddr2','street_address_2','deliveryline2','addr_line2','line2','address line'
            ], 'Street2', inplace = True)

all_AKs["label"].replace(['rstate','mstate','st','stateprovince','stateabbr','state/province','state_code','nea_hm_st',
             'applicant state/province','state_province_cd','rsta','abt_trillium_state_cd','msta','rpm_state',
             'guest_state','regaddrstate','mailingstate','cust_state_nm','prov_state_cd','tsmart_state',
             'state / province','state (us/canada)','regsta','province','svc_state','emp state','state_abbreviation',
             'addressstate','mailing_addresses_state','consumerstatecode','stateorprovince','mailaddrstate',
             'primarystate','home state code','statecode','primary_state','addr_state','state_cd',
             'prim_address_state','countyname','state_prov','residence_addresses_state','stateorpro',
             'new_stateprovincename','region/state','statename','state','st_cd'
            ], 'State', inplace = True)

all_AKs["label"].replace(['postal_code','zipcode','zip_code','rzip','zip code','postalcode','postal code','us_zip_code',
             'applicant zip/postal code','postal_cd','zip ','zip_cd','abt_trillium_zip_cd','mzip','rpm_zip',
             'guest_zip','mailingpostalcode','regaddrzip','cust_postal_cd','emp zip','tsmart_zip',
             'postal code (us/canada)','addresszip5','mailing_addresses_zip','consumerpostalcode','primaryzip',
             'mailaddrzip','mailaddrzip','postal_code_5','zip_code_full','home zip code','primary_zip',
             'zip/postal code','addr_zip','primary_zipcode','citypostalcode','ra_zip','residence_addresses_zip',
             'postal','new_postalcode','zip'
            ], 'Zip', inplace = True)

all_AKs["label"].replace(['zip_code_plus4','zip5','zip4','rzip5','mzip5','zip1','zip+4','zipplus4','nea_hm_zip5','mzip4',
             'zip code + 4 / postal code','postal_zip12_cd','regzip5','postal_zip6_cd','svc_zip','mailaddrzip5',
             'mailaddrzip5','rzip4','zip6','prim_address_zipplusfour','zip9','zip plus 4','postal_code5',
             'reg_zip5','zip_plus_4','plus_4_code','post_cd','zip45'
            ], 'Zip45', inplace = True)

all_AKs["label"].replace(['city','city ''rcity','mcity','city_name','cityname','applicant city','nea_hm_city','abt_trillium_city',
             'rcity','rpm_city','regaddrcity','cust_city_nm','regcity','city_nm','guest_city','mailingcity',
             'city (us/canada)','tsmart_city','svc_city','emp city','mailing_addresses_city','consumercity',
             'mailaddrcity','primarycity','addresscity','home city','primary_city','addr_city','prim_address_city',
             'ra_city','residence_addresses_city','new_city','city'
            ], 'City', inplace = True)

all_AKs["label"].replace(['email','email address','email_address','emailaddress','email_addr','email(s)','email_id',
             'profiles.email_address','emails','primary_email','primary email','primaryemail','e-mail',
             'cust_email_addr','md5_email','email1','email_1','email 1','email2','email_2','email 2',
             'p_email_address','email_3','e-mail address','email_address_','customer_email','email_4',
             'eml','customer email','email addresses'
            ], 'Email', inplace = True)

all_AKs["label"].replace(['hashed_email','md5_email','email_sha1','sha256email1','email1_md5','emailmd5','md5','email_hash',
             'email_md5','md5 hash','sha1','sha1_email','sha256email','email_sha-1','contact_email_sha1',
             'loweremailmd5','email_sha256','md5email','hashed email','md5 email','email hash','hashedemail',
             'lri_g_sha1email1','sha256_email'
            ], 'Hash Email', inplace = True)

all_AKs["label"].replace(['phone1','phone number1','phone'
            ], 'Phone', inplace = True)

all_AKs["label"].replace(['liveramp_cookie_id','liveramp_id','liverampid','liveramp_key','liveramp_cookie','liveramp id'
            ], 'Lr_cook', inplace = True)

all_AKs["label"].replace(['pel','idl','clink','clink_16','pelid','consumer_link','myxid','customer_link','ipel','identitylink',
             'partner_link','mbid','idl_id','lr id 1','lr id 2','lr id 3','lr id 4','lr id 5','lr id 6','lr id 7',
             'lr id 8','lr id 9','lr id 10','liveramp_id 1','individual_id','client customerid','lr_id1',
             'liveramp_id_1','lacconsumer_link','household_link_key'
            ], 'Pel_Idl', inplace = True)

all_AKs["label"].replace(['customerid','customer_id','client customer id','customer id','client_customer_id','custid',
             'cust_id','clientcustomerid','unique_id','user_id','ccid','?customerid','internal customer id',
             'id','fico individual id','individual_key','cs_regid','aiq_indid','aiq_hhid','user id','individual_id',
             'voter file vanid','contactid','luid','pid','pid_id','memberid','clientid','wdid',
             'xid','personid','uuid','ui#','statevoterid','stiristaid','indiv_id','statefileid','mm_uuid','member_id',
             'member id','custno','contact profile.kbm individual id','profile_id','analytics_id','raw_user_id',
             'individual key','dedupe_id','user_sid','account id','pii_cust_key','client_id','customer number',
             'donorid','rnc_regid','luminarid','npi number','partner1 id','speedeonid','kasasa master person id',
             'effo_hh_id','dgid','npi','ind_id','hh_id','person_id','omni_intl_id','lalvoterid','voterbase_id',
             'rnc_reg_id','discovery_contactid','chid_key','lalvoterid','prim_id','vanid','shopcom_household_id',
             'shopcom_individual_id','customer_guid','vendor id','universal_id','cid_id','customer_key',
             'perm_individual_id','customersummary_mastercustomerid','auction_id','custom id',
             'recordid','record_id','record id','record_indicator','cid'
            ], 'Custom Id', inplace = True)

all_AKs["label"].replace(['cookie_id','lrid','deviceid','device id','device_id','xaxisid','cookie','cookie id','device','uid',
             'cookies'
            ], 'Cookie/Device', inplace = True)

all_AKs.replace(['aaid','maid','mobileid','idfa','mobile_id','mobile id'
            ], 'Mobile Ad ID', inplace = True)

all_AKs.replace(['transaction_timestamp', 'event_time','time_stamp','timestamp'
            ], 'Timestamp', inplace = True)

# %%
temp_AK_index_6 = all_AKs.loc[all_AKs['key_index'] == 6]


# 1) filter by key_index = 6
# 2) group by audience ID

# %%
temp_AK_index_6['type'].value_counts()
# Out:
# OfflineLiverampCustomerAccount            412
# OnlineLiverampCustomerAccount              15
# MatchLiverampCustomerAccount                6
# MuidHeidMappingLiverampCustomerAccount      3
# MuidOnlyLiverampCustomerAccount             1
# Name: type, dtype: int64

# %% [markdown]
# # PINless imports analysis

# %% [markdown]
# ## results
# all audiences - 963
# raw email - 183
# CID - 600
# SHA256 - 7
# MD5 - 11
# address - 32
# misc combinations - 129
#
# DS audiences - 103
# address - 6
# raw email - 8
# MD5 - 4
# SHA256 - 1
# CID - 76

# %%
sql = """
WITH
  pinless_audiences AS 

  (
  SELECT
    liveramp_customer_accounts.display_name AS audience_name,
    liveramp_customer_accounts.id AS audience_id,
    COUNT(liveramp_import_requests.id) AS total_imports,
    COUNT(lir_pin_types.id) AS PIN_imports,
    SUM(CASE
        WHEN lir_pin_types.id IS NULL THEN 1
      ELSE
      0
    END
      ) AS PINLESS_imports,
    SAFE_DIVIDE(SUM(CASE
          WHEN lir_pin_types.id IS NULL THEN 1
        ELSE
        0
      END
        ),
      COUNT(liveramp_import_requests.id)) AS percent_pinless
  FROM
    `corp-bi-us-prod.rldb.liveramp_customer_accounts` AS liveramp_customer_accounts
  INNER JOIN
    `corp-bi-us-prod.rldb.customers` AS customers
  ON
    liveramp_customer_accounts.customer_id = customers.id
  INNER JOIN
    `corp-bi-us-prod.rldb.liveramp_import_requests` AS liveramp_import_requests
  ON
    liveramp_customer_accounts.id = liveramp_import_requests.liveramp_customer_account_id
  LEFT JOIN
    `corp-bi-us-prod.rldb.lir_pin_types` AS lir_pin_types
  ON
    liveramp_import_requests.id = lir_pin_types.liveramp_import_request_id
  WHERE
    liveramp_customer_accounts.type = "OfflineLiverampCustomerAccount"
    AND liveramp_customer_accounts.customer_link_audience = FALSE
    AND liveramp_import_requests.status <> 11
  GROUP BY
    1,
    2
  HAVING
    percent_pinless > 0 
    )

  ,
  audience_aks AS 
  (
  SELECT
    audience_key_labels.liveramp_customer_account_id AS table_2_audience_id,
    customers.id AS customer_id,
    customers.name AS customer_name,
    COUNT(audience_key_labels.id) AS ak_count,
    STRING_AGG(LOWER(audience_key_labels.label)) AS aks,
    liveramp_customer_accounts.type
  FROM
    `corp-bi-us-prod.rldb.audience_key_labels` AS audience_key_labels
  INNER JOIN
    `corp-bi-us-prod.rldb.liveramp_customer_accounts` AS liveramp_customer_accounts
  ON
    audience_key_labels.liveramp_customer_account_id = liveramp_customer_accounts.id
  INNER JOIN
    `corp-bi-us-prod.rldb.customers` AS customers
  ON
    liveramp_customer_accounts.customer_id = customers.id
  WHERE
    customers.status = 1
    AND liveramp_customer_accounts.enabled = TRUE
    AND liveramp_customer_accounts.customer_link_audience = FALSE
  GROUP BY
    1,
    2,
    3,
    6
  ORDER BY
    ak_count DESC
    )

SELECT
  audience_id, audience_name, customer_name, customer_id, total_imports, PIN_imports, PINLESS_imports, percent_pinless, ak_count, aks
FROM
  pinless_audiences
INNER JOIN
  audience_aks
ON
  audience_id = table_2_audience_id
"""

pinless_auds = pandas_gbq.read_gbq(sql, project_id='liveramp-ts-bigquery')
# Out:
# Downloading: 100%|██████████| 963/963 [00:00<00:00, 2853.11rows/s]

# %%
pinless_auds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 963 entries, 0 to 962
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   audience_id      963 non-null    int64
#  1   audience_name    963 non-null    object
#  2   customer_name    963 non-null    object
#  3   customer_id      963 non-null    int64
#  4   total_imports    963 non-null    int64
#  5   PIN_imports      963 non-null    int64
#  6   PINLESS_imports  963 non-null    int64
#  7   percent_pinless  963 non-null    float64
#  8   ak_count         963 non-null    int64
#  9   aks              963 non-null    object
# dtypes: float64(1), int64(6), object(3)
# memory usage: 75.4+ KB

# %%
all audiences
- email ak
- CID ak
- address ak

# %%
# audiences w/4-8 aks
pinless_auds_aks_4 = pinless_auds_aks_4[(pinless_auds_aks_4['ak_count'] >= 4) & (pinless_auds_aks_4['ak_count'] <= 8)]
pinless_auds_aks_4.head()
# Out:
#      audience_id                                   audience_name  \
# 32        223236                        AAA - Master Audience v2
# 64        487391                                Webbula - Canada
# 121       231626                      Zeta_CRM_Political Records
# 155       160996                AAA - Master Audience (Billable)
# 207       405921  Oceania Cruises - Facebook Offline Conversions
#
#        customer_name  customer_id  total_imports  PIN_imports  \
# 32               AAA        51274            523          517
# 64           Webbula       400648              4            3
# 121         Zeta CRM        82271             41           40
# 155              AAA        51274            699          693
# 207  Oceania Cruises       551536            135          134
#
#      PINLESS_imports  percent_pinless  ak_count  \
# 32                 6         0.011472         6
# 64                 1         0.250000         6
# 121                1         0.024390         6
# 155                6         0.008584         6
# 207                1         0.007407         6
#
#                                                    aks
# 32     city,state,zip_5,address_1,last_name,first_name
# 64   city,address1,province,last_name,first_name,po...
# 121  lastname,firstname,primaryzip,primarycity,prim...
# 155    city,state,zip_5,address_1,last_name,first_name
# 207       zip,city,state,address1,last_name,first_name

# %%
# audiences w/1 ak
pinless_auds_aks_1 = pinless_auds.loc[pinless_auds['ak_count'] == 1]
pinless_auds_aks_1
# Out:
#      audience_id                           audience_name  \
# 0         117379                      T-Mobile - PII - I
# 1          47236                     Expn - Adhoc (LUID)
# 2         410701                   LR - Competitors - US
# 3         390879                   TTD - DWA US - NetApp
# 4         335869                          123Push-Social
# ..           ...                                     ...
# 958       471841               Vmware MDH -Onboarding US
# 959        79826                TruSignal - NinthDecimal
# 960       310039  MeritDirect (Acxiom EU) - France - PII
# 961       425301                                    Test
# 962       457611                               The Place
#
#                            customer_name  customer_id  total_imports  \
# 0                               T-Mobile       510066            174
# 1                               Experian        18511            753
# 2                                Tableau       592289            882
# 3                           TTD - DWA US       582279             14
# 4                                123Push       578219           3109
# ..                                   ...          ...            ...
# 958                               VMware       569479             21
# 959               TruSignal - Onboarding       388396             42
# 960              MeritDirect (Acxiom EU)       520616             14
# 961                              Lacoste       615291              2
# 962  StackAdapt - Online Marketing Group       608011              2
#
#      PIN_imports  PINLESS_imports  percent_pinless  ak_count  \
# 0            162               12         0.068966         1
# 1             47              706         0.937583         1
# 2            876                6         0.006803         1
# 3             13                1         0.071429         1
# 4           3108                1         0.000322         1
# ..           ...              ...              ...       ...
# 958           18                3         0.142857         1
# 959           41                1         0.023810         1
# 960            6                8         0.571429         1
# 961            1                1         0.500000         1
# 962            0                2         1.000000         1
#
#                     aks
# 0                 attr1
# 1                  luid
# 2    ms_lead_contact_id
# 3                email1
# 4            stiristaid
# ..                  ...
# 958           contactid
# 959            emailmd5
# 960        omni_intl_id
# 961              email1
# 962               email
#
# [839 rows x 10 columns]

# %%
normalized_ak_1 = pd.DataFrame(pinless_auds_aks_1["aks"].value_counts())
normalized_ak_1
# test1.to_csv('/Users/aschul/Documents/Documents - aschul1118mac/Code_Base/Investigations/20200417_AK_analysis/test1.csv')
# Out:
#                                                  aks
# CID                                              600
# email                                            183
# SHA256                                             7
# MD5                                                6
# address1                                           5
# md5                                                4
# phone                                              3
# hashed_email                                       3
# ordinal                                            3
# device id                                          2
# sha256email"                                       2
# email 1                                            2
# ip                                                 2
# matthew staley <matthew.staley@makethunder.com>    2
# zip4                                               2
# usa_email                                          1
# last_name                                          1
# f_name                                             1
# email_addr_txt                                     1
# zip4_proxy                                         1
# zip9                                               1
# zip+4                                              1
# phone1                                             1
# zip_code                                           1
# work email                                         1
# ﻿dh_hh_id                                          1
# phone1_nbr                                         1
# right_email                                        1

# %%
normalized_ak_1 = pinless_auds_aks_1["aks"].replace({"Email":"email", 
                             "Email1":"email",
                             "Email Address":"email",
                             "EmailAddress":"email", 
                             "Emails":"email",
                             "EMAIL":"email",
                             "Email_1":"email",
                             "EmailAddress":"email",
                             "email_address":"email",
                             "EMAIL_ADDRESS":"email",
                             "Email 1":"email",
                             "Email(s)":"email",
                             "email1":"email",
                             "EMAIL_ID":"email",
                             "email1_MD5":"MD5",
                             "emailmd5":"MD5",
                             "profiles.email_address":"email",
                             "EMAIL_ADDR":"email",
                             "SHA256EMAIL1":"email",
                             "email_addr":"email",
                             "MD5EMAIL":"MD5",
                             "EmailAddress":"email",
                             "EMAIL1":"email",
                             "cust_email_addr":"email",
                             "Email_Address":"email",
                             "md5_email":"MD5",
                             "Email_ID":"email",
                             "EMAIL_ADDR_TXT":"email",
                             "emailAddress":"email",
                             "sha1_email":"SHA1",
                             "MD5Email":"MD5",
                             "email_1":"email",
                             "LRI_G_SHA1EMAIL1":"SHA1",
                             "LRI_G_SHA256EMAIL1":"SHA256",
                             "loweremailmd5":"MD5",
                             "email_sha256":"SHA256",
                             "SHA256_EMAIL":"SHA256",
                             "MD5_Email":"MD5",
                             "LRI_DER_SHA256EMAIL1":"SHA256",
                             "email_SHA-1":"SHA1",
                             "sha256email":"SHA256",
                             "email address":"email",
                             "purch_email_addr":"email",
                             "HashedEmail":"hashed_email",
                             "P_EMAIL_ADDRESS":"email",
                             "Member Email Address":"email",
                             "Email Addresses":"email",
                             "email_md5":"MD5",
                             "emails":"email",
                             "Email Hash":"hashed_email",
                             "customer_email":"email",
                             "EMAIL_ADDRESS_":"email",
                             "SHA 256 Email":"SHA256",
                             "EMAILADDRESS":"email",
                             "LRI_DER_SHA1EMAIL1":"SHA1",
                             "email_hash":"hashed_email",
                             "LRI_G_MD5EMAIL1":"MD5",
                             "EMAIL_SHA256":"SHA256",
                             "PII_EMAIL_ADDRESS":"email",
                             "EMail":"email",
                             "Email address":"email",
                             "SHA1_Email":"SHA1",
                             "LRI_DER_MD5EMAIL1":"MD5",
                             "EMAIL_1":"email",
                             "sha256_email":"SHA256",
                             "SHA256EMAIL":"SHA256",
                             "SHA256Email":"email",
                             "emailaddress":"email",
                             "email_id":"email",
                             "SHA1EMAIL":"SHA1",
                             "hashed email":"hashed_email",
                             "SHA256HASHEDEMAIL":"SHA256",
                             "email2":"email",
                             "EMAIL_ADDRESS_1":"email",
                             "md5email":"MD5",
                             "hashedemail":"hashed_email",
                             "EMAIL_HASHED":"hashed_email",
                             "Broker Email":"email",
                             "HASH_MD5_LOWER_EMAIL":"MD5",
                             "profileEmail":"email",
                             "email_Address":"email",
                             "Hashed_Email":"hashed_email",
                             "PER_EMAIL":"email",
                             "Hashed_Email_Address":"email",
                             "Peloton Order Order Email":"email",
                             "EMAIL,FN,LN,,ZIP,CT,PHONE,":"email",
                             "Hashed_Email_ID_Hex":"hashed_email",
                             "#email_lc_md5":"MD5",
                             "MD5_EMAIL":"MD5",
                             "\EMAIL\"":"email",
                             "Customer Email":"email",
                             "CUSTOMERS_SalesOrder_BILLTOLookup::Email":"email",
                             "profile.email":"email",
                             "HASHED_EMAIL":"hashed_email",
                             "sha256email1":"SHA256",
                             "Hashed Email":"hashed_email",
                             "CUST_EMAIL":"email",
                             "SHA256 Email":"SHA256",
                             "email,fn,ln,st,zip,ct,phone,":"email",
                             "best_email":"email",
                             "LRI_G_EMAIL1":"email",
                             "SHA2_EMAIL":"SHA2",
                             "Md5 Email":"MD5",
                             "md5(email1)":"MD5",
                             "master_email":"email",
                             "HASHED_CUST_EMAIL":"hashed_email",
                             "REAL_EMAIL":"email",
                             "email_sha1":"SHA1",
                             "MD5 EMAIL":"MD5",
                             "Email/Email":"email",
                             "hash_email":"hashed_email",
                             "email md5":"MD5",
                             "Email_address":"email",
                             "Email1_SHA-1":"SHA1",
                             "MD5 Hashed Email":"MD5",
                             "EE_EMAIL_ADDRESS":"email",
                             "Email1 Address":"email",
                             "DMD_EMAIL":"email",
                             "QBOVRT_master_email":"email",
                             "lower(b.email_addr_hash_txt)":"hashed_email",
                             "Email1_SHA256":"SHA256",
                             "HashedEmail1":"hashed_email",
                             "CONTACT_EMAIL_ADDR":"email",
                             "Email ":"email",
                             "EmailAddressmd5":"MD5",
                             "CONTACT EMAIL":"email",
                             "MD5EMAIL1":"MD5",
                             "MD5email":"MD5",
                             "sha256email\",470121,624331,470121,UPHE - Onboarding - Salesforce Data\"":"SHA256",
                             "sha256email\",287259,579949,28236,Swirl McGarryBowen - Onboarding\"":"SHA256",
                             "AX_CUREMAIL_10":"email",
                             "Email ":"email",
                             "SHA256_email":"SHA256",
                             "USA_EMAIL":"email",
                             "Right_email":"email",
                             "MDG EMAIL":"MD5",
                             "email3":"email",
                             "sha256email\",287259,579949,28236,Swirl McGarryBowen - Onboarding\"":"SHA256",
                             "sha256email\",470121,624331,470121,UPHE - Onboarding - Salesforce Data\"":"SHA256",
                             "email_SHA_256":"SHA256",
                             "hashed_emailId":"hashed_email",
                             "EMAIL_ADDRESS1":"email",
                             "email_adr1":"email",
                             "EmailAddressHash_MD5":"MD5",
                             "LRI_G_email_address":"email",
                             "DANDRVINSON@EMAIL.COM":"email",
                             "user_email":"email",
                             "Email_hashed":"hashed_email",
                             "P_EMAIL":"email",
                             "Hashed email":"hashed_email",
                             "SHA250Email":"SHA256",
                             "sha256email\",287259,579949,28236,Swirl McGarryBowen - Onboarding\"":"SHA256",
                             "sha256email\",470121,624331,470121,UPHE - Onboarding - Salesforce Data\"":"SHA256",
                             "Email5":"email",
                             "Orders Customer Email":"email",
                             "Encrypted Email address":"hashed_email",
                             "eMail":"email",
                             "patron_email_addr":"email",
                             "Client_Email":"email",
                             "email_01":"email",
                             "emailhash_md5":"MD5",
                             "Person Account: Email":"email",
                             "Email_Appended":"email",
                             "Email_address_hash":"hashed_email",
                             "sha256email\",470121,624331,470121,UPHE - Onboarding - Salesforce Data\"":"SHA256",
                             "EMAIL_HASH":"hashed_email",
                             "Email ID":"email",
                             "email_billing":"email",
                             "PRIMARY_EMAIL_ADDRESS":"email",
                             "Opportunity Email":"email",
                             "CnPh_1_01_Email":"email",
                             "MD5_email":"MD5",
                             "email_address_256hash":"SHA256",
                             "EMAIL ADDR":"email",
                             "sha256email\",154996,542386,15314,StubHub - Salesforce Onboarding\"":"SHA256",
                             "Hash Email":"hashed_email",
                             "prmry_email_addr":"email",
                             "sha256email\",248499,508256,24412,Caesars - Salesforce RFP\"":"SHA256",
                             "MEMBER_EMAIL":"email",
                             "Sha1_Email":"SHA1",
                             "HASH EMAIL ADDR":"hashed_email",
                             "Sha1_Email":"SHA1",
                             "HASH EMAIL ADDR":"hashed_email",
                             "CUS_EMAIL_ADDRESS":"email",
                             "channels.email.address":"email",
                             "\Email1\"\"":"email",
                             "primaryEmail":"email",
                             "sha256email\",313789,533849,313789,Audi - Salesforce Imports\"":"SHA256",
                             "HASEHD_EMAIL":"hashed_email",
                             "\Email1\"\"":"email",
                             "hash email":"hashed_email",
                             "REGI_EMAIL_ADDR":"email",
                             "Customers Email":"email",
                             "email_addres":"email",
                             "sha256email\",116909,533639,11536,Weight Watchers - Onboarding\"":"SHA256",
                             "EMAIL-sha1":"SHA1",
                             "Email Address 1":"email",
                             "Contact Business Email":"email",
                             "\Email1\"\"":"email",
                             "Personal_email":"email",
                             "sha256email\",154996,542386,15314,StubHub - Salesforce Onboarding\"":"SHA256",
                             "EMAIL_MATCH_ID_1":"email",
                             "MD5 Email":"MD5",
                             "associatedemailaddress":"email",
                             "Email_Hash":"hashed_email",
                             "Email_Hash ":"hashed_email",
                             "EMAIL ADDRESS	":"email",
                             "EMAILADDR":"email",
                             "EMAILADDR ":"email",
                             "Contact: Primary Email":"email",
                             "Email Address - Prospects":"email",
                             "sha_email	":"hashed_email",
                             "sha_email":"hashed_email",
                             "primary_contact_primary_email":"email",
                             "EMAIL_ADDR_1":"email",
                             "Primary_Email_Address":"email",
                             "CUST_EMAIL_ADDR":"email",
                             "AlternateEmail":"email",
                             "PERSONEMAIL":"email",
                             "email_address_01":"email"
                            }, inplace = True)

# %%
normalized_ak_1 = pinless_auds_aks_1["aks"].replace(['client customer id','ms_lead_contact_id','ccid','luid','ncs_hhid',
'customer_id','customer id','id','pii_cust_key','pid','uid','cust acct nbr see','audience_key','effo_hh_id',
'customerid','mdg id','record_id','omni_intl_id','guest_id','indiv_id','pel','email1_md5','cust_id','custid',
'synthetic_key_16','personid','ncs_id','individual_id','client_customer_id','unique_id','prim_id','pf_id','cid',
'mstr_persona_key','shopcom_individual_id','person_id','recordid','consumer_link','sid',
'omniindividualidentifier','npi','customer_eid','device_id','employee_id','voter file vanid','eid',
'mcif_hashkey','consumerlink','statefileid','omni_id','clink','rnc_regid','cust_loc_id','content3',
'ax_consumer_link','dib_cust_id','attr1','indiv_srcnbr','voterbase_id','wdid','subscriptionid','dgid',
'dmp_id','cust_key','pid_id','spotify_id','lalid','lacconsumer_link','dncvanidstate','stiristaid','vkey',
'compassbus','scr_cust_key','dlx_id','leadcontact_email','addressid','customer_key','lalvoterid',
'clientcustomerid','xaxisid','spel','dimcustomerid','account_id','orderheaderid','member_id',
'household_link_key','address_hash','contactid','accountkey','sp_id','consumerid','authlaser','recipient_id',
'leadid','individual id','party_id','customernbr','hash_record_id','cust_srcid','individual_mc','seuci','rowid',
'gsnid','person_link_key','ppid','id (customers)','movio id','cntct_id','fico individual id','indv_id',
'aiq_biz_contact_cons_id','bp_number','prospect_key','enterprise_cust_id','acx_cons_link','dl acct#',
'perm_individual_id','dig_atz','raw_user_id','client_id','subscriber_id','count.uuid','user id','hub_cust_id',
'chd_id','cust_eid','customer_eid_txt','luminarid','internal id','audiencekey1','tdhashkey','field1','dh_id',
'plunge_id','customer_guid','profile_id','donorid','liveramp_swm_id','bp number',
'wmx_g_1.vt_individual_customer_id','personseqno','traid','rdhhmtchcd',' client customer id','abilitec_id',
'test_one','pid_best','mbid','massive_id','wxdid','sciid','homephone','hashed_cust_email','consumer_id',
'person_mcode','providerid','cardholder_id','person_seq_no','st/zip/matchcd','hashed_atom_customer_id',
'statevoterid','infoscout_user_id','base_sixty_four_id','take_two_id','peloton order order email',
'key','user_uuid','order_id','bpid','synthetic id','last name','snapchat_id','campaign_individual_id',
'abt_cl','per_id','pdiid','mstr_indv_id','guid','npi_number','ai_id','bp_id','ncsid','fwmhhid',
'respondent_id_enc','62f60293db8028bcd6a70d5b82e5a25ba082db05ba3b836b99b0acc79cb039af','analytics_id',
'recipient id','ucdmid','cs_regid','oltaxid','unique id','claritas_key','#norton_customer_id','mbrship_id',
'md5hashemail','guest_hshld_id','dspid','Ôªødh_hh_id','cust-id','sha 256 email','roku_id',
'9bd705d54111e806c8ffe22bc66700a6','goldencustomerid','abilitec_indv_id','bhf_identifier','myxid'], 'CID', 
                                          inplace = True)
# Out:
# /Users/aschul/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
DS audiences
- email ak
- CID ak
- address ak

# %% [markdown]
# query PINless, DS audiences

# %%
sql = """
WITH
  pinless_audiences AS 

  (
  SELECT
    liveramp_customer_accounts.display_name AS audience_name,
    liveramp_customer_accounts.id AS audience_id,
    COUNT(liveramp_import_requests.id) AS total_imports,
    COUNT(lir_pin_types.id) AS PIN_imports,
    SUM(CASE
        WHEN lir_pin_types.id IS NULL THEN 1
      ELSE
      0
    END
      ) AS PINLESS_imports,
    SAFE_DIVIDE(SUM(CASE
          WHEN lir_pin_types.id IS NULL THEN 1
        ELSE
        0
      END
        ),
      COUNT(liveramp_import_requests.id)) AS percent_pinless
  FROM
    `corp-bi-us-prod.rldb.liveramp_customer_accounts` AS liveramp_customer_accounts
  INNER JOIN
    `corp-bi-us-prod.rldb.customers` AS customers
  ON
    liveramp_customer_accounts.customer_id = customers.id
  INNER JOIN
    `corp-bi-us-prod.rldb.liveramp_import_requests` AS liveramp_import_requests
  ON
    liveramp_customer_accounts.id = liveramp_import_requests.liveramp_customer_account_id
  LEFT JOIN
    `corp-bi-us-prod.rldb.lir_pin_types` AS lir_pin_types
  ON
    liveramp_import_requests.id = lir_pin_types.liveramp_import_request_id
  WHERE
    liveramp_customer_accounts.type = "OfflineLiverampCustomerAccount"
    AND liveramp_customer_accounts.customer_link_audience = FALSE
    AND liveramp_import_requests.status <> 11
  GROUP BY
    1,
    2
  HAVING
    percent_pinless > 0 
    )

  ,
  audience_aks AS 
  (
  SELECT
    audience_key_labels.liveramp_customer_account_id AS table_2_audience_id,
    customers.id AS customer_id,
    customers.name AS customer_name,
    COUNT(audience_key_labels.id) AS ak_count,
    STRING_AGG(LOWER(audience_key_labels.label)) AS aks,
    liveramp_customer_accounts.type
  FROM
    `corp-bi-us-prod.rldb.audience_key_labels` AS audience_key_labels
  INNER JOIN
    `corp-bi-us-prod.rldb.liveramp_customer_accounts` AS liveramp_customer_accounts
  ON
    audience_key_labels.liveramp_customer_account_id = liveramp_customer_accounts.id
  INNER JOIN
    `corp-bi-us-prod.rldb.customers` AS customers
  ON
    liveramp_customer_accounts.customer_id = customers.id
  WHERE
    customers.status = 1
    AND liveramp_customer_accounts.enabled = TRUE
    AND liveramp_customer_accounts.customer_link_audience = FALSE
  GROUP BY
    1,
    2,
    3,
    6
  ORDER BY
    ak_count DESC
    )

SELECT
  audience_id, audience_name, customer_name, customer_id, total_imports, PIN_imports, PINLESS_imports, percent_pinless, ak_count, aks
FROM
  pinless_audiences
INNER JOIN
  audience_aks
ON
  audience_id = table_2_audience_id
WHERE audience_id IN (
              SELECT
                lr_customer_accounts.id
              FROM
                `corp-bi-us-prod.rldb.dms_segments` AS dms_segments
              INNER JOIN
                `corp-bi-us-prod.rldb.lrc_field_definitions` AS lrc_field_definitions
              ON
                dms_segments.lrc_field_definition_id = lrc_field_definitions.id
              INNER JOIN
                `corp-bi-us-prod.rldb.liveramp_customer_accounts` AS lr_customer_accounts
              ON
                lrc_field_definitions.lr_customer_account_id = lr_customer_accounts.id
              INNER JOIN
                `corp-bi-us-prod.rldb.customers` AS customers
              ON
                lr_customer_accounts.customer_id = customers.id
              WHERE
                lr_customer_accounts.enabled = TRUE
                AND lr_customer_accounts.customer_link_audience = FALSE
                AND customers.status = 1
              GROUP BY
                lr_customer_accounts.id) 
"""
pinless_auds_ds = pandas_gbq.read_gbq(sql, project_id='liveramp-ts-bigquery')
# Out:
# Downloading: 100%|██████████| 103/103 [00:00<00:00, 462.76rows/s]

# %%
pinless_auds_ds
# Out:
#      audience_id                                      audience_name  \
# 0         156516           Pacific Data Partners - Custom Audiences
# 1         189526                                 Chegg - Data Store
# 2          48226                   Compass - B2B Counts (Unique ID)
# 3         325439                                   Custom Audiences
# 4         341589                        Epsilon - Custom Individual
# 5         352589                                     ALC Cust Aud 1
# 6         105849                           Medicx - zip4 onboarding
# 7           6558                  Expn - Digital Master File (LUID)
# 8         285629                                   123Push-Consumer
# 9         113419  Affinity Solutions - Onboarding - Name and Postal
# 10         51336                              TruSignal - DMS - md5
# 11        329809               PeoplefindersDaaS - Custom Audiences
# 12        190526                            FourthWall - Massive ID
# 13        450351                                  D&B - TV Segments
# 14        388519                                   DMD - Data Store
# 15        170556                   Polk IHS - Data Store - Standard
# 16        107579                          NCS - Syndicated Segments
# 17        120509                             IRI - Custom Audiences
# 18        312689                       Bombora (Facebook 3rd Party)
# 19        231896   D&B - Individual (CLINKs Only) - Reach Expansion
# 20         22356                                      Webbula - B2B
# 21         67766                              Datalogix - Auto Data
# 22          5798                                    V12 - Data [3p]
# 23        251119                                  Healio - INV Test
# 24         14736                Alliant - Full Dataset (Individual)
# 25         31386                      Fourthwall - STB Distribution
# 26        274009              Everyday Health Consumer - onboarding
# 27         67166                       GOP Data Trust - Voters INDV
# 28        158906                       Claritas - PRIZM (PII-based)
# 29           251                                           Dataline
# 30         75046            Datastream Group - DMS - Auto Insurance
# 31        173286             TargetSmart - Main Audience - NATIONAL
# 32         66626                                    Experian - Auto
# 33        156786                     Polk IHS - Data Store - Custom
# 34        333819                                 Illion - Australia
# 35         33406              Fluent - Individual - Reach Expansion
# 36        346689                                     IRI - Annalect
# 37        411771                       NCS - TV Segments (NAP-only)
# 38         49866                  Compass - US Business (Unique ID)
# 39         71896                              TellTale - Onboarding
# 40        490361                                Datastream_Group_SV
# 41        357249               MeritDirect (Acxiom EU) - EMEA - PII
# 42        243229                      HealthLink Dimensions - AdHoc
# 43        487901                  Eric's Test Audience (HH Offline)
# 44         80316                       Pacific Data Partners - Main
# 45        392826              [training] Kirstie Thoum - Onboarding
# 46         77496                      D&B - Household (CLINK + PII)
# 47        490371                                Datastream_Group_CD
# 48        390369        Quotient - SID - Offline Data - NEW 08.2019
# 49         60996                             Webbula - DMS Audience
# 50        310049     MeritDirect (Acxiom EU) - United Kingdom - PII
# 51        473071               AmeribaseDigital - Homebound and WFH
# 52        183056                                Crossix - HCP - PII
# 53        184166                                        Visa Custom
# 54         14906                 Alliant - Full Dataset (Household)
# 55        403231                                  Mastercard - Zip4
# 56        274199     D&B - Household (CLINK +PII) - Reach Expansion
# 57        289079                           NWD Consumer - Household
# 58        335869                                     123Push-Social
# 59         47236                                Expn - Adhoc (LUID)
# 60        161136                         V12 - Individual Data [3p]
# 61         88026                     D&B - Individual (CLINKs Only)
# 62        240969  Quotient - SID - Offline Data (Standard Segments)
# 63         86876                         MedData Group - Onboarding
# 64           121                                        IXI Digital
# 65        307809                       Custom - Household - X Graph
# 66        201556         Kantar - People and Society - US - Cohorts
# 67        142919          NinthDecimal - Custom Data Store Segments
# 68        362019                           NCS - Custom Target 2019
# 69        486991                                    NCS DS - Amazon
# 70        310039             MeritDirect (Acxiom EU) - France - PII
# 71         65836                         L2 Political - Voters INDV
# 72         50116                         Bridge - Household (Email)
# 73        391676                                Alliant - HH Custom
# 74        307829                      Custom - Individual - X Graph
# 75        381369               Freeosk - Syndicated Segments - INDV
# 76        263139            MeritDirect (Acxiom EU) - Germany - PII
# 77        438351                          180byTwo - Cosmos - Exact
# 78        225489                                      Ultimate Data
# 79        107589                              NCS - Custom segments
# 80         32936                          MeritDirect - OmniDigital
# 81         83246                      Datastream Group - DMS - Auto
# 82        134979                  Naiqu's Car Store - Car Customers
# 83        326309                   Cinemark - Match Test - testfile
# 84         67776                               Datalogix - CPG Data
# 85        461031                                            general
# 86        113519               Epsilon - Evergreen Custom Household
# 87        265739                            Experian - PII Segments
# 88        253029              Johnson & Johnson - DataGuru Segments
# 89        222906                           PeoplefindersDaaS - Main
# 90         38906                 AnalyticsIQ - Comprehensive (MAIN)
# 91        241489                                    Visa Syndicated
# 92        175266                        Category and brand shoppers
# 93         26146                                      TiVo Research
# 94        258699  Kantar - HomeScores - US - In Home Consumer Te...
# 95        225289         Live Nation - Fanbase – ALL – Signal File
# 96        387379                NCS - Custom Target 2019 Individual
# 97        320109                          180byTWO - Simple Onboard
# 98         56166                         ALC - Political (Extended)
# 99         47876                                 Expn - Adhoc (PID)
# 100        65846                           L2 Political - Voters HH
# 101        83236             Datastream Group - DMS - Digital Optin
# 102        29316                                      Geoscape Data
#
#                                 customer_name  customer_id  total_imports  \
# 0                       Pacific Data Partners       519776            971
# 1                                       Chegg       513836            343
# 2                           Compass Marketing       238301            156
# 3                                     NetWise       506336            294
# 4                                     Epsilon       576169            421
# 5                                         ALC       437078            145
# 6                                      Medicx       530769            236
# 7                                    Experian        18511            133
# 8                                     123Push       578219            597
# 9                          Affinity Solutions       425718             82
# 10                                  TruSignal       515376           7410
# 11                          PeoplefindersDaaS       560186            899
# 12                     FourthWall Media, Inc.       474158            265
# 13                                        D&B       359691             20
# 14                                        DMD       551676             97
# 15      Polk Audience Solutions by IHS Markit       511996            113
# 16                                        NCS       297891           3329
# 17                                        IRI       516316          10459
# 18               Bombora (Facebook 3rd Party)       587469             43
# 19                                        D&B       359691            535
# 20                                    Webbula       400648             42
# 21                         Datalogix (Oracle)        47164            119
# 22                                        V12       144191            372
# 23                                     Healio       518946            556
# 24                                    Alliant       436078            189
# 25                     FourthWall Media, Inc.       474158            103
# 26   Everyday Health - Consumer  (Ziff Davis)       572639             39
# 27                                 Data Trust       506866            587
# 28                                   Claritas       538859             12
# 29                                   Dataline       111451             47
# 30                           Datastream Group       514616             13
# 31                                TargetSmart       531449           1286
# 32                                   Experian        18511              3
# 33      Polk Audience Solutions by IHS Markit       511996            634
# 34                                     illion       592889            538
# 35                                     Fluent       341441            192
# 36                                        IRI       516316            517
# 37                                        NCS       297891             65
# 38                          Compass Marketing       238301            164
# 39                                     Healio       518946           2207
# 40                           Datastream Group       514616             49
# 41                    MeritDirect (Acxiom EU)       520616             12
# 42                      HealthLink Dimensions       557566            809
# 43        Eric's Electronics Internal Company       586779              2
# 44                      Pacific Data Partners       519776           2043
# 45                     TRAINING Kirstie Thoum       607546              4
# 46                                        D&B       359691           6628
# 47                           Datastream Group       514616             84
# 48                                   Quotient       216241           4546
# 49                                    Webbula       400648             79
# 50                    MeritDirect (Acxiom EU)       520616             14
# 51        Lighthouse List - Ameribase Digital       521086            796
# 52                                    Crossix       507496             32
# 53                                       Visa       546826            638
# 54                                    Alliant       436078            293
# 55                                 Mastercard       509076             48
# 56                                        D&B       359691            463
# 57                                    NetWise       506336             11
# 58                                    123Push       578219           3109
# 59                                   Experian        18511            753
# 60                                        V12       144191             43
# 61                                        D&B       359691           6598
# 62                                   Quotient       216241           8606
# 63                              MedData Group       520486           3219
# 64                                IXI Digital        47644             68
# 65                                  Infogroup        39144            598
# 66                                     Kantar       360641              6
# 67                   NinthDecimal - TruSignal       528216           2033
# 68                                        NCS       297891           5452
# 69                            NCS DS - Amazon       627311            101
# 70                    MeritDirect (Acxiom EU)       520616             14
# 71                               L2 Political       515476           1820
# 72                                     Bridge       506009          26295
# 73                                    Alliant       436078            153
# 74                                  Infogroup        39144            800
# 75                                    Freeosk       596779            171
# 76                    MeritDirect (Acxiom EU)       520616             14
# 77                                   180byTWO       531379            749
# 78                              Ultimate Data       560856          40993
# 79                                        NCS       297891           8773
# 80                                MeritDirect       434788            121
# 81                           Datastream Group       514616             52
# 82                          Naiqu's Car Store       536139              8
# 83                                   Cinemark       552646              2
# 84                         Datalogix (Oracle)        47164            254
# 85                                   Windfall       520876            188
# 86                                    Epsilon       576169           1613
# 87                         Experian Australia       565669           1294
# 88               LinkedIn - Johnson & Johnson       570329             11
# 89                          PeoplefindersDaaS       560186           4956
# 90                                AnalyticsIQ       500619            355
# 91                                       Visa       546826            510
# 92                                 SavingStar       538949             59
# 93                                       TiVo       509006            866
# 94                                     Kantar       360641              2
# 95                                Live Nation       441858           6181
# 96                                        NCS       297891            187
# 97                                   180byTWO       531379             16
# 98                                        ALC       437078              7
# 99                                   Experian        18511            222
# 100                              L2 Political       515476            252
# 101                          Datastream Group       514616             62
# 102                                  Geoscape       190211              2
#
#      PIN_imports  PINLESS_imports  percent_pinless  ak_count  \
# 0             24              947         0.975283         1
# 1            342                1         0.002915         1
# 2            155                1         0.006410         1
# 3            291                3         0.010204         1
# 4            399               22         0.052257         7
# 5            141                4         0.027586         7
# 6            230                6         0.025424         1
# 7             47               86         0.646617         1
# 8            595                2         0.003350         1
# 9             76                6         0.073171         1
# 10          7409                1         0.000135         1
# 11            15              884         0.983315         1
# 12            19              246         0.928302         1
# 13             4               16         0.800000         1
# 14            94                3         0.030928         1
# 15            89               24         0.212389         1
# 16            29             3300         0.991289         1
# 17            23            10436         0.997801         1
# 18            42                1         0.023256         1
# 19             2              533         0.996262         1
# 20            41                1         0.023810         6
# 21             6              113         0.949580         1
# 22           371                1         0.002688         1
# 23             3              553         0.994604         1
# 24           165               24         0.126984         1
# 25            20               83         0.805825         1
# 26            37                2         0.051282         1
# 27           581                6         0.010221         1
# 28            11                1         0.083333         1
# 29            46                1         0.021277         1
# 30            11                2         0.153846         1
# 31          1285                1         0.000778         1
# 32             2                1         0.333333         1
# 33           633                1         0.001577         1
# 34           537                1         0.001859         1
# 35           191                1         0.005208         1
# 36             2              515         0.996132         1
# 37             1               64         0.984615         1
# 38           163                1         0.006098         1
# 39            19             2188         0.991391         1
# 40            12               37         0.755102         1
# 41             4                8         0.666667         1
# 42           807                2         0.002472         1
# 43             1                1         0.500000         2
# 44            20             2023         0.990210         1
# 45             2                2         0.500000         1
# 46            14             6614         0.997888         1
# 47            24               60         0.714286         1
# 48           355             4191         0.921909         1
# 49            78                1         0.012658         5
# 50             6                8         0.571429         1
# 51           795                1         0.001256         1
# 52            31                1         0.031250         1
# 53           634                4         0.006270         1
# 54           189              104         0.354949         1
# 55            47                1         0.020833         1
# 56             4              459         0.991361         1
# 57             9                2         0.181818         1
# 58          3108                1         0.000322         1
# 59            47              706         0.937583         1
# 60            42                1         0.023256         1
# 61             4             6594         0.999394         1
# 62            66             8540         0.992331         1
# 63           192             3027         0.940354         1
# 64            66                2         0.029412         1
# 65           597                1         0.001672         1
# 66             1                5         0.833333         1
# 67          2031                2         0.000984         1
# 68            19             5433         0.996515         1
# 69            10               91         0.900990         1
# 70             6                8         0.571429         1
# 71            66             1754         0.963736         1
# 72         26293                2         0.000076         1
# 73           152                1         0.006536         1
# 74           797                3         0.003750         1
# 75           170                1         0.005848         1
# 76             6                8         0.571429         1
# 77           747                2         0.002670         7
# 78         40992                1         0.000024         1
# 79            25             8748         0.997150         1
# 80            96               25         0.206612         1
# 81            47                5         0.096154         1
# 82             7                1         0.125000         1
# 83             1                1         0.500000         1
# 84             8              246         0.968504         1
# 85           187                1         0.005319         1
# 86          1549               64         0.039678         7
# 87          1293                1         0.000773         1
# 88             0               11         1.000000         1
# 89            60             4896         0.987893         1
# 90           349                6         0.016901         2
# 91           504                6         0.011765         1
# 92            56                3         0.050847         1
# 93            32              834         0.963048         1
# 94             1                1         0.500000         1
# 95          6177                4         0.000647         1
# 96            16              171         0.914439         1
# 97            15                1         0.062500         1
# 98             6                1         0.142857         1
# 99            45              177         0.797297         1
# 100           39              213         0.845238         1
# 101           53                9         0.145161         1
# 102            1                1         0.500000         1
#
#                                                    aks
# 0                                                pf_id
# 1                                            user_uuid
# 2                                           compassbus
# 3                                            person_id
# 4    zip,city,state,last_name,first_name,address_li...
# 5    zip,city,state,lastname,zipplus4,firstname,add...
# 6                                                 zip9
# 7                                                  eid
# 8                                           stiristaid
# 9                                   client_customer_id
# 10                                            emailmd5
# 11                                               pf_id
# 12                                          massive_id
# 13                                           record_id
# 14                                                dgid
# 15                                          rdhhmtchcd
# 16                                              ncs_id
# 17                                    synthetic_key_16
# 18                                       sha 256 email
# 19                                           record_id
# 20        city,zip5,state,address,last_name,first_name
# 21                                              dlx_id
# 22                                              dmp_id
# 23                                         customer id
# 24                                     person_link_key
# 25                                             fwmhhid
# 26                                  client customer id
# 27                                           rnc_regid
# 28                                        claritas_key
# 29                                            dl acct#
# 30                                                  id
# 31                                        voterbase_id
# 32                                                luid
# 33                                      st/zip/matchcd
# 34                                            md5email
# 35                                               email
# 36                                    synthetic_key_16
# 37                                            ncs_hhid
# 38                                          compassbus
# 39                                         customer id
# 40                                                  id
# 41                                        omni_intl_id
# 42                                          providerid
# 43                                  lastname,firstname
# 44                                               pf_id
# 45                                               email
# 46                                           record_id
# 47                                                  id
# 48                                                 sid
# 49            city,email1,address,last_name,first_name
# 50                                        omni_intl_id
# 51                                               email
# 52                                               clink
# 53                                               zip+4
# 54                                  household_link_key
# 55                                          zip4_proxy
# 56                                           record_id
# 57                                           person_id
# 58                                          stiristaid
# 59                                                luid
# 60                                              dmp_id
# 61                                           record_id
# 62                                                 sid
# 63                                              mdg id
# 64                                                zip4
# 65                                            recordid
# 66                               shopcom_individual_id
# 67                                            emailmd5
# 68                                            ncs_hhid
# 69                                            ncs_hhid
# 70                                        omni_intl_id
# 71                                               lalid
# 72                                               email
# 73                                        analytics_id
# 74                                            recordid
# 75                                       email_address
# 76                                        omni_intl_id
# 77   zip,city,state,last_name,first_name,primary_ad...
# 78                                                wdid
# 79                                              ncs_id
# 80                                             omni_id
# 81                                                  id
# 82                                         customer id
# 83                                              email1
# 84                                              dlx_id
# 85                                                  id
# 86   zip,city,state,lastname,address_line_1,address...
# 87                                         sha256email
# 88                                                 pel
# 89                                               pf_id
# 90                                  aiq_hhid,aiq_indid
# 91                                                zip4
# 92                    9bd705d54111e806c8ffe22bc66700a6
# 93                                               traid
# 94                                               sciid
# 95                                               email
# 96                                            ncs_hhid
# 97                                              email1
# 98                                  perm_individual_id
# 99                                                 pid
# 100                                              lalid
# 101                                                 id
# 102                                                 id

# %%
pinless_auds_ds_1 = pinless_auds_DS[(pinless_auds_DS.ak_count == 1)]

# %%
pinless_auds_ds_1
# Out:
#      audience_id                                      audience_name  \
# 0         156516           Pacific Data Partners - Custom Audiences
# 1         189526                                 Chegg - Data Store
# 2          48226                   Compass - B2B Counts (Unique ID)
# 3         325439                                   Custom Audiences
# 6         105849                           Medicx - zip4 onboarding
# 7           6558                  Expn - Digital Master File (LUID)
# 8         285629                                   123Push-Consumer
# 9         113419  Affinity Solutions - Onboarding - Name and Postal
# 10         51336                              TruSignal - DMS - md5
# 11        329809               PeoplefindersDaaS - Custom Audiences
# 12        190526                            FourthWall - Massive ID
# 13        450351                                  D&B - TV Segments
# 14        388519                                   DMD - Data Store
# 15        170556                   Polk IHS - Data Store - Standard
# 16        107579                          NCS - Syndicated Segments
# 17        120509                             IRI - Custom Audiences
# 18        312689                       Bombora (Facebook 3rd Party)
# 19        231896   D&B - Individual (CLINKs Only) - Reach Expansion
# 21         67766                              Datalogix - Auto Data
# 22          5798                                    V12 - Data [3p]
# 23        251119                                  Healio - INV Test
# 24         14736                Alliant - Full Dataset (Individual)
# 25         31386                      Fourthwall - STB Distribution
# 26        274009              Everyday Health Consumer - onboarding
# 27         67166                       GOP Data Trust - Voters INDV
# 28        158906                       Claritas - PRIZM (PII-based)
# 29           251                                           Dataline
# 30         75046            Datastream Group - DMS - Auto Insurance
# 31        173286             TargetSmart - Main Audience - NATIONAL
# 32         66626                                    Experian - Auto
# 33        156786                     Polk IHS - Data Store - Custom
# 34        333819                                 Illion - Australia
# 35         33406              Fluent - Individual - Reach Expansion
# 36        346689                                     IRI - Annalect
# 37        411771                       NCS - TV Segments (NAP-only)
# 38         49866                  Compass - US Business (Unique ID)
# 39         71896                              TellTale - Onboarding
# 40        490361                                Datastream_Group_SV
# 41        357249               MeritDirect (Acxiom EU) - EMEA - PII
# 42        243229                      HealthLink Dimensions - AdHoc
# 44         80316                       Pacific Data Partners - Main
# 45        392826              [training] Kirstie Thoum - Onboarding
# 46         77496                      D&B - Household (CLINK + PII)
# 47        490371                                Datastream_Group_CD
# 48        390369        Quotient - SID - Offline Data - NEW 08.2019
# 50        310049     MeritDirect (Acxiom EU) - United Kingdom - PII
# 51        473071               AmeribaseDigital - Homebound and WFH
# 52        183056                                Crossix - HCP - PII
# 53        184166                                        Visa Custom
# 54         14906                 Alliant - Full Dataset (Household)
# 55        403231                                  Mastercard - Zip4
# 56        274199     D&B - Household (CLINK +PII) - Reach Expansion
# 57        289079                           NWD Consumer - Household
# 58        335869                                     123Push-Social
# 59         47236                                Expn - Adhoc (LUID)
# 60        161136                         V12 - Individual Data [3p]
# 61         88026                     D&B - Individual (CLINKs Only)
# 62        240969  Quotient - SID - Offline Data (Standard Segments)
# 63         86876                         MedData Group - Onboarding
# 64           121                                        IXI Digital
# 65        307809                       Custom - Household - X Graph
# 66        201556         Kantar - People and Society - US - Cohorts
# 67        142919          NinthDecimal - Custom Data Store Segments
# 68        362019                           NCS - Custom Target 2019
# 69        486991                                    NCS DS - Amazon
# 70        310039             MeritDirect (Acxiom EU) - France - PII
# 71         65836                         L2 Political - Voters INDV
# 72         50116                         Bridge - Household (Email)
# 73        391676                                Alliant - HH Custom
# 74        307829                      Custom - Individual - X Graph
# 75        381369               Freeosk - Syndicated Segments - INDV
# 76        263139            MeritDirect (Acxiom EU) - Germany - PII
# 78        225489                                      Ultimate Data
# 79        107589                              NCS - Custom segments
# 80         32936                          MeritDirect - OmniDigital
# 81         83246                      Datastream Group - DMS - Auto
# 82        134979                  Naiqu's Car Store - Car Customers
# 83        326309                   Cinemark - Match Test - testfile
# 84         67776                               Datalogix - CPG Data
# 85        461031                                            general
# 87        265739                            Experian - PII Segments
# 88        253029              Johnson & Johnson - DataGuru Segments
# 89        222906                           PeoplefindersDaaS - Main
# 91        241489                                    Visa Syndicated
# 92        175266                        Category and brand shoppers
# 93         26146                                      TiVo Research
# 94        258699  Kantar - HomeScores - US - In Home Consumer Te...
# 95        225289         Live Nation - Fanbase – ALL – Signal File
# 96        387379                NCS - Custom Target 2019 Individual
# 97        320109                          180byTWO - Simple Onboard
# 98         56166                         ALC - Political (Extended)
# 99         47876                                 Expn - Adhoc (PID)
# 100        65846                           L2 Political - Voters HH
# 101        83236             Datastream Group - DMS - Digital Optin
# 102        29316                                      Geoscape Data
#
#                                 customer_name  customer_id  total_imports  \
# 0                       Pacific Data Partners       519776            971
# 1                                       Chegg       513836            343
# 2                           Compass Marketing       238301            156
# 3                                     NetWise       506336            294
# 6                                      Medicx       530769            236
# 7                                    Experian        18511            133
# 8                                     123Push       578219            597
# 9                          Affinity Solutions       425718             82
# 10                                  TruSignal       515376           7410
# 11                          PeoplefindersDaaS       560186            899
# 12                     FourthWall Media, Inc.       474158            265
# 13                                        D&B       359691             20
# 14                                        DMD       551676             97
# 15      Polk Audience Solutions by IHS Markit       511996            113
# 16                                        NCS       297891           3329
# 17                                        IRI       516316          10459
# 18               Bombora (Facebook 3rd Party)       587469             43
# 19                                        D&B       359691            535
# 21                         Datalogix (Oracle)        47164            119
# 22                                        V12       144191            372
# 23                                     Healio       518946            556
# 24                                    Alliant       436078            189
# 25                     FourthWall Media, Inc.       474158            103
# 26   Everyday Health - Consumer  (Ziff Davis)       572639             39
# 27                                 Data Trust       506866            587
# 28                                   Claritas       538859             12
# 29                                   Dataline       111451             47
# 30                           Datastream Group       514616             13
# 31                                TargetSmart       531449           1286
# 32                                   Experian        18511              3
# 33      Polk Audience Solutions by IHS Markit       511996            634
# 34                                     illion       592889            538
# 35                                     Fluent       341441            192
# 36                                        IRI       516316            517
# 37                                        NCS       297891             65
# 38                          Compass Marketing       238301            164
# 39                                     Healio       518946           2207
# 40                           Datastream Group       514616             49
# 41                    MeritDirect (Acxiom EU)       520616             12
# 42                      HealthLink Dimensions       557566            809
# 44                      Pacific Data Partners       519776           2043
# 45                     TRAINING Kirstie Thoum       607546              4
# 46                                        D&B       359691           6628
# 47                           Datastream Group       514616             84
# 48                                   Quotient       216241           4546
# 50                    MeritDirect (Acxiom EU)       520616             14
# 51        Lighthouse List - Ameribase Digital       521086            796
# 52                                    Crossix       507496             32
# 53                                       Visa       546826            638
# 54                                    Alliant       436078            293
# 55                                 Mastercard       509076             48
# 56                                        D&B       359691            463
# 57                                    NetWise       506336             11
# 58                                    123Push       578219           3109
# 59                                   Experian        18511            753
# 60                                        V12       144191             43
# 61                                        D&B       359691           6598
# 62                                   Quotient       216241           8606
# 63                              MedData Group       520486           3219
# 64                                IXI Digital        47644             68
# 65                                  Infogroup        39144            598
# 66                                     Kantar       360641              6
# 67                   NinthDecimal - TruSignal       528216           2033
# 68                                        NCS       297891           5452
# 69                            NCS DS - Amazon       627311            101
# 70                    MeritDirect (Acxiom EU)       520616             14
# 71                               L2 Political       515476           1820
# 72                                     Bridge       506009          26295
# 73                                    Alliant       436078            153
# 74                                  Infogroup        39144            800
# 75                                    Freeosk       596779            171
# 76                    MeritDirect (Acxiom EU)       520616             14
# 78                              Ultimate Data       560856          40993
# 79                                        NCS       297891           8773
# 80                                MeritDirect       434788            121
# 81                           Datastream Group       514616             52
# 82                          Naiqu's Car Store       536139              8
# 83                                   Cinemark       552646              2
# 84                         Datalogix (Oracle)        47164            254
# 85                                   Windfall       520876            188
# 87                         Experian Australia       565669           1294
# 88               LinkedIn - Johnson & Johnson       570329             11
# 89                          PeoplefindersDaaS       560186           4956
# 91                                       Visa       546826            510
# 92                                 SavingStar       538949             59
# 93                                       TiVo       509006            866
# 94                                     Kantar       360641              2
# 95                                Live Nation       441858           6181
# 96                                        NCS       297891            187
# 97                                   180byTWO       531379             16
# 98                                        ALC       437078              7
# 99                                   Experian        18511            222
# 100                              L2 Political       515476            252
# 101                          Datastream Group       514616             62
# 102                                  Geoscape       190211              2
#
#      PIN_imports  PINLESS_imports  percent_pinless  ak_count  \
# 0             24              947         0.975283         1
# 1            342                1         0.002915         1
# 2            155                1         0.006410         1
# 3            291                3         0.010204         1
# 6            230                6         0.025424         1
# 7             47               86         0.646617         1
# 8            595                2         0.003350         1
# 9             76                6         0.073171         1
# 10          7409                1         0.000135         1
# 11            15              884         0.983315         1
# 12            19              246         0.928302         1
# 13             4               16         0.800000         1
# 14            94                3         0.030928         1
# 15            89               24         0.212389         1
# 16            29             3300         0.991289         1
# 17            23            10436         0.997801         1
# 18            42                1         0.023256         1
# 19             2              533         0.996262         1
# 21             6              113         0.949580         1
# 22           371                1         0.002688         1
# 23             3              553         0.994604         1
# 24           165               24         0.126984         1
# 25            20               83         0.805825         1
# 26            37                2         0.051282         1
# 27           581                6         0.010221         1
# 28            11                1         0.083333         1
# 29            46                1         0.021277         1
# 30            11                2         0.153846         1
# 31          1285                1         0.000778         1
# 32             2                1         0.333333         1
# 33           633                1         0.001577         1
# 34           537                1         0.001859         1
# 35           191                1         0.005208         1
# 36             2              515         0.996132         1
# 37             1               64         0.984615         1
# 38           163                1         0.006098         1
# 39            19             2188         0.991391         1
# 40            12               37         0.755102         1
# 41             4                8         0.666667         1
# 42           807                2         0.002472         1
# 44            20             2023         0.990210         1
# 45             2                2         0.500000         1
# 46            14             6614         0.997888         1
# 47            24               60         0.714286         1
# 48           355             4191         0.921909         1
# 50             6                8         0.571429         1
# 51           795                1         0.001256         1
# 52            31                1         0.031250         1
# 53           634                4         0.006270         1
# 54           189              104         0.354949         1
# 55            47                1         0.020833         1
# 56             4              459         0.991361         1
# 57             9                2         0.181818         1
# 58          3108                1         0.000322         1
# 59            47              706         0.937583         1
# 60            42                1         0.023256         1
# 61             4             6594         0.999394         1
# 62            66             8540         0.992331         1
# 63           192             3027         0.940354         1
# 64            66                2         0.029412         1
# 65           597                1         0.001672         1
# 66             1                5         0.833333         1
# 67          2031                2         0.000984         1
# 68            19             5433         0.996515         1
# 69            10               91         0.900990         1
# 70             6                8         0.571429         1
# 71            66             1754         0.963736         1
# 72         26293                2         0.000076         1
# 73           152                1         0.006536         1
# 74           797                3         0.003750         1
# 75           170                1         0.005848         1
# 76             6                8         0.571429         1
# 78         40992                1         0.000024         1
# 79            25             8748         0.997150         1
# 80            96               25         0.206612         1
# 81            47                5         0.096154         1
# 82             7                1         0.125000         1
# 83             1                1         0.500000         1
# 84             8              246         0.968504         1
# 85           187                1         0.005319         1
# 87          1293                1         0.000773         1
# 88             0               11         1.000000         1
# 89            60             4896         0.987893         1
# 91           504                6         0.011765         1
# 92            56                3         0.050847         1
# 93            32              834         0.963048         1
# 94             1                1         0.500000         1
# 95          6177                4         0.000647         1
# 96            16              171         0.914439         1
# 97            15                1         0.062500         1
# 98             6                1         0.142857         1
# 99            45              177         0.797297         1
# 100           39              213         0.845238         1
# 101           53                9         0.145161         1
# 102            1                1         0.500000         1
#
#                     aks
# 0                   CID
# 1                   CID
# 2                   CID
# 3                   CID
# 6                  zip9
# 7                   CID
# 8                   CID
# 9                   CID
# 10                  MD5
# 11                  MD5
# 12                  CID
# 13                  CID
# 14                  CID
# 15                  CID
# 16                  CID
# 17                  CID
# 18                  CID
# 19                  CID
# 21                  CID
# 22                  CID
# 23                  CID
# 24                  CID
# 25                  CID
# 26                  CID
# 27                  CID
# 28                  CID
# 29                  CID
# 30                  CID
# 31                  CID
# 32                  CID
# 33                  CID
# 34                  MD5
# 35                email
# 36                  CID
# 37                  CID
# 38                  CID
# 39                  CID
# 40                  CID
# 41                  CID
# 42                  CID
# 44   lastname,firstname
# 45                email
# 46                  CID
# 47                  CID
# 48                  CID
# 50                  CID
# 51                email
# 52                  CID
# 53                zip+4
# 54                  CID
# 55           zip4_proxy
# 56                  CID
# 57                  CID
# 58                  CID
# 59                  CID
# 60                  CID
# 61                  CID
# 62                  CID
# 63                  CID
# 64                 zip4
# 65                  CID
# 66                  CID
# 67                  MD5
# 68                  CID
# 69                  CID
# 70                  CID
# 71                  CID
# 72                email
# 73                  CID
# 74                  CID
# 75                email
# 76                  CID
# 78                  CID
# 79                  CID
# 80                  CID
# 81                  CID
# 82                  CID
# 83                email
# 84                  CID
# 85                  CID
# 87               SHA256
# 88                  CID
# 89                  CID
# 91                 zip4
# 92                  CID
# 93                  CID
# 94                  CID
# 95                email
# 96                  CID
# 97                email
# 98                  CID
# 99                  CID
# 100                 CID
# 101                 CID
# 102                 CID

# %%
pinless_auds_ds_1["aks"].replace(['client customer id','ms_lead_contact_id','ccid','luid','ncs_hhid',
'customer_id','customer id','id','pii_cust_key','pid','uid','cust acct nbr see','audience_key','effo_hh_id',
'customerid','mdg id','record_id','omni_intl_id','guest_id','indiv_id','pel','email1_md5','cust_id','custid',
'synthetic_key_16','personid','ncs_id','individual_id','client_customer_id','unique_id','prim_id','pf_id','cid',
'mstr_persona_key','shopcom_individual_id','person_id','recordid','consumer_link','sid',
'omniindividualidentifier','npi','customer_eid','device_id','employee_id','voter file vanid','eid',
'mcif_hashkey','consumerlink','statefileid','omni_id','clink','rnc_regid','cust_loc_id','content3',
'ax_consumer_link','dib_cust_id','attr1','indiv_srcnbr','voterbase_id','wdid','subscriptionid','dgid',
'dmp_id','cust_key','pid_id','spotify_id','lalid','lacconsumer_link','dncvanidstate','stiristaid','vkey',
'compassbus','scr_cust_key','dlx_id','leadcontact_email','addressid','customer_key','lalvoterid',
'clientcustomerid','xaxisid','spel','dimcustomerid','account_id','orderheaderid','member_id',
'household_link_key','address_hash','contactid','accountkey','sp_id','consumerid','authlaser','recipient_id',
'leadid','individual id','party_id','customernbr','hash_record_id','cust_srcid','individual_mc','seuci','rowid',
'gsnid','person_link_key','ppid','id (customers)','movio id','cntct_id','fico individual id','indv_id',
'aiq_biz_contact_cons_id','bp_number','prospect_key','enterprise_cust_id','acx_cons_link','dl acct#',
'perm_individual_id','dig_atz','raw_user_id','client_id','subscriber_id','count.uuid','user id','hub_cust_id',
'chd_id','cust_eid','customer_eid_txt','luminarid','internal id','audiencekey1','tdhashkey','field1','dh_id',
'plunge_id','customer_guid','profile_id','donorid','liveramp_swm_id','bp number',
'wmx_g_1.vt_individual_customer_id','personseqno','traid','rdhhmtchcd',' client customer id','abilitec_id',
'test_one','pid_best','mbid','massive_id','wxdid','sciid','homephone','hashed_cust_email','consumer_id',
'person_mcode','providerid','cardholder_id','person_seq_no','st/zip/matchcd','hashed_atom_customer_id',
'statevoterid','infoscout_user_id','base_sixty_four_id','take_two_id','peloton order order email',
'key','user_uuid','order_id','bpid','synthetic id','last name','snapchat_id','campaign_individual_id',
'abt_cl','per_id','pdiid','mstr_indv_id','guid','npi_number','ai_id','bp_id','ncsid','fwmhhid',
'respondent_id_enc','62f60293db8028bcd6a70d5b82e5a25ba082db05ba3b836b99b0acc79cb039af','analytics_id',
'recipient id','ucdmid','cs_regid','oltaxid','unique id','claritas_key','#norton_customer_id','mbrship_id',
'md5hashemail','guest_hshld_id','dspid','Ôªødh_hh_id','cust-id','sha 256 email','roku_id',
'9bd705d54111e806c8ffe22bc66700a6','goldencustomerid','abilitec_indv_id','bhf_identifier','myxid'], 'CID', 
                                          inplace = True)
# Out:
# /Users/aschul/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
pinless_auds_ds_1_values = pd.DataFrame(pinless_auds_ds_1["aks"].value_counts())
pinless_auds_ds_1_values
# Out:
#                     aks
# CID                  76
# email                 8
# MD5                   4
# zip4                  2
# zip9                  1
# SHA256                1
# zip4_proxy            1
# zip+4                 1
# lastname,firstname    1

# %%
pinless_auds_ds_1["aks"].replace({"Email":"email", 
                             "Email1":"email",
                             "Email Address":"email",
                             "EmailAddress":"email", 
                             "Emails":"email",
                             "EMAIL":"email",
                             "Email_1":"email",
                             "EmailAddress":"email",
                             "email_address":"email",
                             "EMAIL_ADDRESS":"email",
                             "Email 1":"email",
                             "Email(s)":"email",
                             "email1":"email",
                             "EMAIL_ID":"email",
                             "email1_MD5":"MD5",
                             "emailmd5":"MD5",
                             "profiles.email_address":"email",
                             "EMAIL_ADDR":"email",
                             "SHA256EMAIL1":"email",
                             "email_addr":"email",
                             "MD5EMAIL":"MD5",
                             "EmailAddress":"email",
                             "EMAIL1":"email",
                             "cust_email_addr":"email",
                             "Email_Address":"email",
                             "md5_email":"MD5",
                             "Email_ID":"email",
                             "EMAIL_ADDR_TXT":"email",
                             "emailAddress":"email",
                             "sha1_email":"SHA1",
                             "MD5Email":"MD5",
                             "email_1":"email",
                             "LRI_G_SHA1EMAIL1":"SHA1",
                             "LRI_G_SHA256EMAIL1":"SHA256",
                             "loweremailmd5":"MD5",
                             "email_sha256":"SHA256",
                             "SHA256_EMAIL":"SHA256",
                             "MD5_Email":"MD5",
                             "LRI_DER_SHA256EMAIL1":"SHA256",
                             "email_SHA-1":"SHA1",
                             "sha256email":"SHA256",
                             "email address":"email",
                             "purch_email_addr":"email",
                             "HashedEmail":"hashed_email",
                             "P_EMAIL_ADDRESS":"email",
                             "Member Email Address":"email",
                             "Email Addresses":"email",
                             "email_md5":"MD5",
                             "emails":"email",
                             "Email Hash":"hashed_email",
                             "customer_email":"email",
                             "EMAIL_ADDRESS_":"email",
                             "SHA 256 Email":"SHA256",
                             "EMAILADDRESS":"email",
                             "LRI_DER_SHA1EMAIL1":"SHA1",
                             "email_hash":"hashed_email",
                             "LRI_G_MD5EMAIL1":"MD5",
                             "EMAIL_SHA256":"SHA256",
                             "PII_EMAIL_ADDRESS":"email",
                             "EMail":"email",
                             "Email address":"email",
                             "SHA1_Email":"SHA1",
                             "LRI_DER_MD5EMAIL1":"MD5",
                             "EMAIL_1":"email",
                             "sha256_email":"SHA256",
                             "SHA256EMAIL":"SHA256",
                             "SHA256Email":"email",
                             "emailaddress":"email",
                             "email_id":"email",
                             "SHA1EMAIL":"SHA1",
                             "hashed email":"hashed_email",
                             "SHA256HASHEDEMAIL":"SHA256",
                             "email2":"email",
                             "EMAIL_ADDRESS_1":"email",
                             "md5email":"MD5",
                             "hashedemail":"hashed_email",
                             "EMAIL_HASHED":"hashed_email",
                             "Broker Email":"email",
                             "HASH_MD5_LOWER_EMAIL":"MD5",
                             "profileEmail":"email",
                             "email_Address":"email",
                             "Hashed_Email":"hashed_email",
                             "PER_EMAIL":"email",
                             "Hashed_Email_Address":"email",
                             "Peloton Order Order Email":"email",
                             "EMAIL,FN,LN,,ZIP,CT,PHONE,":"email",
                             "Hashed_Email_ID_Hex":"hashed_email",
                             "#email_lc_md5":"MD5",
                             "MD5_EMAIL":"MD5",
                             "\EMAIL\"":"email",
                             "Customer Email":"email",
                             "CUSTOMERS_SalesOrder_BILLTOLookup::Email":"email",
                             "profile.email":"email",
                             "HASHED_EMAIL":"hashed_email",
                             "sha256email1":"SHA256",
                             "Hashed Email":"hashed_email",
                             "CUST_EMAIL":"email",
                             "SHA256 Email":"SHA256",
                             "email,fn,ln,st,zip,ct,phone,":"email",
                             "best_email":"email",
                             "LRI_G_EMAIL1":"email",
                             "SHA2_EMAIL":"SHA2",
                             "Md5 Email":"MD5",
                             "md5(email1)":"MD5",
                             "master_email":"email",
                             "HASHED_CUST_EMAIL":"hashed_email",
                             "REAL_EMAIL":"email",
                             "email_sha1":"SHA1",
                             "MD5 EMAIL":"MD5",
                             "Email/Email":"email",
                             "hash_email":"hashed_email",
                             "email md5":"MD5",
                             "Email_address":"email",
                             "Email1_SHA-1":"SHA1",
                             "MD5 Hashed Email":"MD5",
                             "EE_EMAIL_ADDRESS":"email",
                             "Email1 Address":"email",
                             "DMD_EMAIL":"email",
                             "QBOVRT_master_email":"email",
                             "lower(b.email_addr_hash_txt)":"hashed_email",
                             "Email1_SHA256":"SHA256",
                             "HashedEmail1":"hashed_email",
                             "CONTACT_EMAIL_ADDR":"email",
                             "Email ":"email",
                             "EmailAddressmd5":"MD5",
                             "CONTACT EMAIL":"email",
                             "MD5EMAIL1":"MD5",
                             "MD5email":"MD5",
                             "sha256email\",470121,624331,470121,UPHE - Onboarding - Salesforce Data\"":"SHA256",
                             "sha256email\",287259,579949,28236,Swirl McGarryBowen - Onboarding\"":"SHA256",
                             "AX_CUREMAIL_10":"email",
                             "Email ":"email",
                             "SHA256_email":"SHA256",
                             "USA_EMAIL":"email",
                             "Right_email":"email",
                             "MDG EMAIL":"MD5",
                             "email3":"email",
                             "sha256email\",287259,579949,28236,Swirl McGarryBowen - Onboarding\"":"SHA256",
                             "sha256email\",470121,624331,470121,UPHE - Onboarding - Salesforce Data\"":"SHA256",
                             "email_SHA_256":"SHA256",
                             "hashed_emailId":"hashed_email",
                             "EMAIL_ADDRESS1":"email",
                             "email_adr1":"email",
                             "EmailAddressHash_MD5":"MD5",
                             "LRI_G_email_address":"email",
                             "DANDRVINSON@EMAIL.COM":"email",
                             "user_email":"email",
                             "Email_hashed":"hashed_email",
                             "P_EMAIL":"email",
                             "Hashed email":"hashed_email",
                             "SHA250Email":"SHA256",
                             "sha256email\",287259,579949,28236,Swirl McGarryBowen - Onboarding\"":"SHA256",
                             "sha256email\",470121,624331,470121,UPHE - Onboarding - Salesforce Data\"":"SHA256",
                             "Email5":"email",
                             "Orders Customer Email":"email",
                             "Encrypted Email address":"hashed_email",
                             "eMail":"email",
                             "patron_email_addr":"email",
                             "Client_Email":"email",
                             "email_01":"email",
                             "emailhash_md5":"MD5",
                             "Person Account: Email":"email",
                             "Email_Appended":"email",
                             "Email_address_hash":"hashed_email",
                             "sha256email\",470121,624331,470121,UPHE - Onboarding - Salesforce Data\"":"SHA256",
                             "EMAIL_HASH":"hashed_email",
                             "Email ID":"email",
                             "email_billing":"email",
                             "PRIMARY_EMAIL_ADDRESS":"email",
                             "Opportunity Email":"email",
                             "CnPh_1_01_Email":"email",
                             "MD5_email":"MD5",
                             "email_address_256hash":"SHA256",
                             "EMAIL ADDR":"email",
                             "sha256email\",154996,542386,15314,StubHub - Salesforce Onboarding\"":"SHA256",
                             "Hash Email":"hashed_email",
                             "prmry_email_addr":"email",
                             "sha256email\",248499,508256,24412,Caesars - Salesforce RFP\"":"SHA256",
                             "MEMBER_EMAIL":"email",
                             "Sha1_Email":"SHA1",
                             "HASH EMAIL ADDR":"hashed_email",
                             "Sha1_Email":"SHA1",
                             "HASH EMAIL ADDR":"hashed_email",
                             "CUS_EMAIL_ADDRESS":"email",
                             "channels.email.address":"email",
                             "\Email1\"\"":"email",
                             "primaryEmail":"email",
                             "sha256email\",313789,533849,313789,Audi - Salesforce Imports\"":"SHA256",
                             "HASEHD_EMAIL":"hashed_email",
                             "\Email1\"\"":"email",
                             "hash email":"hashed_email",
                             "REGI_EMAIL_ADDR":"email",
                             "Customers Email":"email",
                             "email_addres":"email",
                             "sha256email\",116909,533639,11536,Weight Watchers - Onboarding\"":"SHA256",
                             "EMAIL-sha1":"SHA1",
                             "Email Address 1":"email",
                             "Contact Business Email":"email",
                             "\Email1\"\"":"email",
                             "Personal_email":"email",
                             "sha256email\",154996,542386,15314,StubHub - Salesforce Onboarding\"":"SHA256",
                             "EMAIL_MATCH_ID_1":"email",
                             "MD5 Email":"MD5",
                             "associatedemailaddress":"email",
                             "Email_Hash":"hashed_email",
                             "Email_Hash ":"hashed_email",
                             "EMAIL ADDRESS	":"email",
                             "EMAILADDR":"email",
                             "EMAILADDR ":"email",
                             "Contact: Primary Email":"email",
                             "Email Address - Prospects":"email",
                             "sha_email	":"hashed_email",
                             "sha_email":"hashed_email",
                             "primary_contact_primary_email":"email",
                             "EMAIL_ADDR_1":"email",
                             "Primary_Email_Address":"email",
                             "CUST_EMAIL_ADDR":"email",
                             "AlternateEmail":"email",
                             "PERSONEMAIL":"email",
                             "email_address_01":"email"
                            }, inplace = True)
# Out:
# /Users/aschul/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %% [markdown]
# # PINless imports analysis archive

# %% [markdown]
# query 1: ak info
#
# SELECT
#   audience_key_labels.liveramp_customer_account_id,
#   customers.id AS customer_id,
#   customers.name AS customer_name,
#   COUNT(audience_key_labels.id) AS ak_count,
#   STRING_AGG(LOWER(audience_key_labels.label)) AS aks,
#   liveramp_customer_accounts.type
# FROM
#   `corp-bi-us-prod.rldb.audience_key_labels` AS audience_key_labels
# INNER JOIN
#   `corp-bi-us-prod.rldb.liveramp_customer_accounts` AS liveramp_customer_accounts
# ON
#   audience_key_labels.liveramp_customer_account_id = liveramp_customer_accounts.id
# INNER JOIN
#   `corp-bi-us-prod.rldb.customers` AS customers
# ON
#   liveramp_customer_accounts.customer_id = customers.id
# WHERE
#   customers.status = 1
#   AND liveramp_customer_accounts.enabled = TRUE
#   AND liveramp_customer_accounts.customer_link_audience = FALSE
# GROUP BY
#   1,
#   2,
#   3,
#   6
# ORDER BY
#   ak_count DESC

# %%
query 2: pinless info
    
SELECT
  liveramp_customer_accounts.display_name AS audience_name,
  liveramp_customer_accounts.id AS audience_id,
  customers.name AS customer_name,
  customers.id AS customer_id, 
  COUNT(liveramp_import_requests.id) AS total_imports,
  COUNT(lir_pin_types.id) AS PIN_imports,
  SUM(CASE
      WHEN lir_pin_types.id IS NULL THEN 1
    ELSE
    0
  END
    ) AS PINLESS_imports,
  SAFE_DIVIDE(SUM(CASE
        WHEN lir_pin_types.id IS NULL THEN 1
      ELSE
      0
    END
      ),
    COUNT(liveramp_import_requests.id)) AS percent_pinless
FROM
  `corp-bi-us-prod.rldb.liveramp_customer_accounts` AS liveramp_customer_accounts
INNER JOIN
  `corp-bi-us-prod.rldb.customers` AS customers
ON
  liveramp_customer_accounts.customer_id = customers.id
INNER JOIN
  `corp-bi-us-prod.rldb.liveramp_import_requests` AS liveramp_import_requests
ON
  liveramp_customer_accounts.id = liveramp_import_requests.liveramp_customer_account_id
LEFT JOIN
  `corp-bi-us-prod.rldb.lir_pin_types` AS lir_pin_types
ON
  liveramp_import_requests.id = lir_pin_types.liveramp_import_request_id
WHERE
  liveramp_customer_accounts.type = "OfflineLiverampCustomerAccount"
  AND liveramp_customer_accounts.customer_link_audience = FALSE
  AND liveramp_import_requests.status <> 11 
GROUP BY
  audience_id,
  audience_name,
  customer_name,
  customer_id
HAVING percent_pinless > 0

# %%
query 3: combined
WITH
  pinless_audiences AS 

  (
  SELECT
    liveramp_customer_accounts.display_name AS audience_name,
    liveramp_customer_accounts.id AS audience_id,
    COUNT(liveramp_import_requests.id) AS total_imports,
    COUNT(lir_pin_types.id) AS PIN_imports,
    SUM(CASE
        WHEN lir_pin_types.id IS NULL THEN 1
      ELSE
      0
    END
      ) AS PINLESS_imports,
    SAFE_DIVIDE(SUM(CASE
          WHEN lir_pin_types.id IS NULL THEN 1
        ELSE
        0
      END
        ),
      COUNT(liveramp_import_requests.id)) AS percent_pinless
  FROM
    `corp-bi-us-prod.rldb.liveramp_customer_accounts` AS liveramp_customer_accounts
  INNER JOIN
    `corp-bi-us-prod.rldb.customers` AS customers
  ON
    liveramp_customer_accounts.customer_id = customers.id
  INNER JOIN
    `corp-bi-us-prod.rldb.liveramp_import_requests` AS liveramp_import_requests
  ON
    liveramp_customer_accounts.id = liveramp_import_requests.liveramp_customer_account_id
  LEFT JOIN
    `corp-bi-us-prod.rldb.lir_pin_types` AS lir_pin_types
  ON
    liveramp_import_requests.id = lir_pin_types.liveramp_import_request_id
  WHERE
    liveramp_customer_accounts.type = "OfflineLiverampCustomerAccount"
    AND liveramp_customer_accounts.customer_link_audience = FALSE
    AND liveramp_import_requests.status <> 11
  GROUP BY
    1,
    2
  HAVING
    percent_pinless > 0 
    )

  ,
  audience_aks AS 
  (
  SELECT
    audience_key_labels.liveramp_customer_account_id AS table_2_audience_id,
    customers.id AS customer_id,
    customers.name AS customer_name,
    COUNT(audience_key_labels.id) AS ak_count,
    STRING_AGG(LOWER(audience_key_labels.label)) AS aks,
    liveramp_customer_accounts.type
  FROM
    `corp-bi-us-prod.rldb.audience_key_labels` AS audience_key_labels
  INNER JOIN
    `corp-bi-us-prod.rldb.liveramp_customer_accounts` AS liveramp_customer_accounts
  ON
    audience_key_labels.liveramp_customer_account_id = liveramp_customer_accounts.id
  INNER JOIN
    `corp-bi-us-prod.rldb.customers` AS customers
  ON
    liveramp_customer_accounts.customer_id = customers.id
  WHERE
    customers.status = 1
    AND liveramp_customer_accounts.enabled = TRUE
    AND liveramp_customer_accounts.customer_link_audience = FALSE
  GROUP BY
    1,
    2,
    3,
    6
  ORDER BY
    ak_count DESC
    )

SELECT
  audience_id, audience_name, customer_name, customer_id, total_imports, PIN_imports, PINLESS_imports, percent_pinless, ak_count, aks
FROM
  pinless_audiences
INNER JOIN
  audience_aks
ON
  audience_id = table_2_audience_id

# %% [markdown]
# ```mysql
# SELECT
#   liveramp_customer_accounts.display_name AS audience_name,
#   liveramp_customer_accounts.id AS audience_id,
#   customers.name AS customer_name,
#   customers.id AS customer_id,
#   COUNT(liveramp_import_requests.id) AS total_imports,
#   COUNT(lir_pin_types.id) AS PIN_imports,
#   SUM(CASE
#       WHEN lir_pin_types.id IS NULL THEN 1
#     ELSE
#     0
#   END
#     ) AS PINLESS_imports,
#   SAFE_DIVIDE(SUM(CASE
#         WHEN lir_pin_types.id IS NULL THEN 1
#       ELSE
#       0
#     END
#       ),
#     COUNT(liveramp_import_requests.id)) AS percent_pinless
# FROM
#   `corp-bi-us-prod.rldb.liveramp_customer_accounts` AS liveramp_customer_accounts
# INNER JOIN
#   `corp-bi-us-prod.rldb.customers` AS customers
# ON
#   liveramp_customer_accounts.customer_id = customers.id
# INNER JOIN
#   `corp-bi-us-prod.rldb.liveramp_import_requests` AS liveramp_import_requests
# ON
#   liveramp_customer_accounts.id = liveramp_import_requests.liveramp_customer_account_id
# LEFT JOIN
#   `corp-bi-us-prod.rldb.lir_pin_types` AS lir_pin_types
# ON
#   liveramp_import_requests.id = lir_pin_types.liveramp_import_request_id
# WHERE
#   liveramp_customer_accounts.type = "OfflineLiverampCustomerAccount"
#   AND liveramp_customer_accounts.customer_link_audience = FALSE
#   AND liveramp_import_requests.status <> 11
# GROUP BY
#   audience_id,
#   audience_name,
#   customer_name,
#   customer_id
# ```

# %%
pinless_imports = pd.read_csv('/Users/aschul/Documents/Documents - aschul1118mac/Code_Base/Investigations/20200417_AK_analysis/PINless_workflow_audiences/PINLESS_imports.csv')

# %%
pinless_imports
# Out:
#                                           audience_name  audience_id  \
# 0                        D&B - Individual (CLINKs Only)        88026
# 1         Kantar - Shopcom - US - Retailer Brands - Raw       221586
# 2     Kantar - Shopcom - US - Retailer Brands - Buye...       228576
# 3                                   Walmart - LUID Omni       232826
# 4                           DSPolitical - VAN CoOp - HH        87796
# ...                                                 ...          ...
# 1198                         RedPoint-Xanterra-Windstar       361999
# 1199                         Bridge - Household (Email)        50116
# 1200                           Sephora - BlueCore Files       301939
# 1201                                      Ultimate Data       225489
# 1202                                    AdWerx - Direct        57606
#
#                    customer_name  customer_id  total_imports  PIN_imports  \
# 0                            D&B       359691           6598            4
# 1                         Kantar       360641           1537            1
# 2                         Kantar       360641            927            1
# 3                        Walmart       508766           3530            6
# 4                    DSPolitical       422918           2851            5
# ...                          ...          ...            ...          ...
# 1198  RedPoint-Xanterra-Windstar       599579           9460         9459
# 1199                      Bridge       506009          26295        26293
# 1200                     Sephora       505949          22750        22749
# 1201               Ultimate Data       560856          40993        40992
# 1202                      Adwerx       515496         170449       170448
#
#       PINLESS_imports  percent_pinless
# 0                6594         0.999394
# 1                1536         0.999349
# 2                 926         0.998921
# 3                3524         0.998300
# 4                2846         0.998246
# ...               ...              ...
# 1198                1         0.000106
# 1199                2         0.000076
# 1200                1         0.000044
# 1201                1         0.000024
# 1202                1         0.000006
#
# [1203 rows x 8 columns]

# %%
pinless_imports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1203 entries, 0 to 1202
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   audience_name    1203 non-null   object
#  1   audience_id      1203 non-null   int64
#  2   customer_name    1203 non-null   object
#  3   customer_id      1203 non-null   int64
#  4   total_imports    1203 non-null   int64
#  5   PIN_imports      1203 non-null   int64
#  6   PINLESS_imports  1203 non-null   int64
#  7   percent_pinless  1203 non-null   float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 75.3+ KB

# %%
pinless_imports.describe()
# Out:
#          audience_id    customer_id  total_imports    PIN_imports  \
# count    1203.000000    1203.000000    1203.000000    1203.000000
# mean   260806.205320  476237.852037     725.029925     569.708229
# std    159391.660671  160801.223523    5295.860074    5239.255205
# min       121.000000      31.000000       2.000000       1.000000
# 25%    106919.000000  434788.000000       7.000000       3.000000
# 50%    279859.000000  521286.000000      31.000000      15.000000
# 75%    410756.000000  582989.000000     340.500000     177.000000
# max    500061.000000  630111.000000  170449.000000  170448.000000
#
#        PINLESS_imports  percent_pinless
# count      1203.000000      1203.000000
# mean        155.321696         0.294101
# std         776.999077         0.308814
# min           1.000000         0.000006
# 25%           1.000000         0.022347
# 50%           2.000000         0.198265
# 75%           8.000000         0.500000
# max       10436.000000         0.999394

# %%
tasks
2a) pull AKs for all audiences
2b) filter by top 25% of percent_pinless
3) filter for data store audiences
4) interactive slider w/selectable band of percent_pinless
# for tuesday, sum(key_index) for address audiences, join AKs + pinless audiences

# %%
above_50 = pinless_imports[pinless_imports["percent_pinless"]>0.19]

# %%
above_50
# Out:
#                                          audience_name  audience_id  \
# 0                       D&B - Individual (CLINKs Only)        88026
# 1        Kantar - Shopcom - US - Retailer Brands - Raw       221586
# 2    Kantar - Shopcom - US - Retailer Brands - Buye...       228576
# 3                                  Walmart - LUID Omni       232826
# 4                          DSPolitical - VAN CoOp - HH        87796
# ..                                                 ...          ...
# 601                             ownerIQ - Office Depot       370729
# 602                        Sam's Club - IRI Onboarding       227246
# 603                             US Bank - MCIF PII New       167226
# 604                              Digilant - Onboarding       453051
# 605                         State Farm - Prospect File       121249
#
#     customer_name  customer_id  total_imports  PIN_imports  PINLESS_imports  \
# 0             D&B       359691           6598            4             6594
# 1          Kantar       360641           1537            1             1536
# 2          Kantar       360641            927            1              926
# 3         Walmart       508766           3530            6             3524
# 4     DSPolitical       422918           2851            5             2846
# ..            ...          ...            ...          ...              ...
# 601       ownerIQ       140601           1614         1294              320
# 602    Sam's Club       386956          15275        12249             3026
# 603       US Bank       518396             36           29                7
# 604      Digilant       393628             62           50               12
# 605    State Farm       510529             21           17                4
#
#      percent_pinless
# 0           0.999394
# 1           0.999349
# 2           0.998921
# 3           0.998300
# 4           0.998246
# ..               ...
# 601         0.198265
# 602         0.198101
# 603         0.194444
# 604         0.193548
# 605         0.190476
#
# [606 rows x 8 columns]

# %%
percent_pinless.plot.hist()
